# %% [markdown]
# # Rectangular integration using rpca + WNN

# %%
source("path/preprocess/utils.R") 
setwd("path")
library(gridExtra)
library(RColorBrewer)
# Out:
# Attaching SeuratObject
#
# Registered S3 method overwritten by 'SeuratDisk':
#   method            from
#   as.sparse.H5Group Seurat
#
# Loading required package: ensembldb
#
# Loading required package: BiocGenerics
#
#
# Attaching package: 'BiocGenerics'
#
#
# The following objects are masked from 'package:stats':
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from 'package:base':
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: S4Vectors
#
#
# Attaching package: 'S4Vectors'
#
#
# The following object is masked from 'package:future':
#
#     values
#
#
# The following objects are masked from 'package:base':
#
#     I, expand.grid, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: GenomicFeatures
#
# Loading required package: AnnotationDbi
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: AnnotationFilter
#
#
# Attaching package: 'AnnotationFilter'
#
#
# The following object is masked from 'package:future':
#
#     value
#
#
#
# Attaching package: 'ensembldb'
#
#
# The following object is masked from 'package:stats':
#
#     filter
#
#
# Loading required package: BSgenome
#
# Loading required package: Biostrings
#
# Loading required package: XVector
#
#
# Attaching package: 'Biostrings'
#
#
# The following object is masked from 'package:base':
#
#     strsplit
#
#
# Loading required package: rtracklayer
#
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:Biostrings':
#
#     collapse, intersect, setdiff, setequal, union
#
#
# The following object is masked from 'package:XVector':
#
#     slice
#
#
# The following objects are masked from 'package:ensembldb':
#
#     filter, select
#
#
# The following object is masked from 'package:AnnotationDbi':
#
#     select
#
#
# The following object is masked from 'package:Biobase':
#
#     combine
#
#
# The following objects are masked from 'package:GenomicRanges':
#
#     intersect, setdiff, union
#
#
# The following object is masked from 'package:GenomeInfoDb':
#
#     intersect
#
#
# The following objects are masked from 'package:IRanges':
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from 'package:S4Vectors':
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from 'package:BiocGenerics':
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: 'Matrix'
#
#
# The following object is masked from 'package:S4Vectors':
#
#     expand
#
#
#
# Attaching package: 'purrr'
#
#
# The following object is masked from 'package:XVector':
#
#     compact
#
#
# The following object is masked from 'package:GenomicRanges':
#
#     reduce
#
#
# The following object is masked from 'package:IRanges':
#
#     reduce
#
#
# The following object is masked from 'package:Signac':
#
#     reduce
#
#
#
# Attaching package: 'gridExtra'
#
#
# The following object is masked from 'package:dplyr':
#
#     combine
#
#
# The following object is masked from 'package:Biobase':
#
#     combine
#
#
# The following object is masked from 'package:BiocGenerics':
#
#     combine

# %%
output_dir <- pj("result", "comparison", 'wnn_full_cellmask', 'increamental_integration_rpca')
mkdir(output_dir, remove_old = F)

K <- parseTOML("configs/model.toml")[["default"]]$dim_c
l <- 7.5  # figure size
L <- 10   # figure size
m <- 0.5  # legend margin

# %%
rna_all <- LoadH5Seurat('path/data/raw/rna+adt/wnn/rna_cellmask.h5seurat')
adt_all <- LoadH5Seurat('path/data/raw/rna+adt/wnn/adt_cellmask.h5seurat')
# Out:
# Validating h5Seurat file
#
# Initializing rna with data
#
# Adding counts for rna
#
# Adding miscellaneous information for rna
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results
#
# Validating h5Seurat file
#
# Initializing adt with data
#
# Adding counts for adt
#
# Adding miscellaneous information for adt
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results

# %%
rna <- rna_all[, rna_all[['batch']]=='p1_0' | rna_all[['batch']]=='p2_0']
adt <- adt_all[, adt_all[['batch']]=='p1_0' | adt_all[['batch']]=='p2_0']

# %%
obj <- rna
obj[["adt"]] <- CreateAssayObject(counts = adt@assays$adt@counts)
obj
# Out:
# An object of class Seurat
# 3841 features across 10120 samples within 2 assays
# Active assay: rna (3617 features, 0 variable features)
#  1 other assay present: adt

# %% [markdown]
# # P1 and P2

# %%
obj_rna <- GetAssayData(object = obj, assay = "rna")
obj_rna <- CreateSeuratObject(counts = obj_rna, assay = "rna")
obj_rna@meta.data$l1 <- rna[['l1']]
obj_rna@meta.data$batch <- rna[['batch']]
obj_rna.list <- SplitObject(obj_rna, split.by = "batch")
obj_rna.list <- lapply(X = obj_rna.list, FUN = function(x) {
    x <- NormalizeData(x)
    x <- FindVariableFeatures(x, nfeatures = 5000)
})

rna_features <- SelectIntegrationFeatures(object.list = obj_rna.list, nfeatures = 5000)
obj_rna.list <- lapply(X = obj_rna.list, FUN = function(x) {
    x <- ScaleData(x, features = rna_features, verbose = FALSE)
    x <- RunPCA(x, features = rna_features, verbose = FALSE, reduction.name = "pca")
})

rna.anchors <- FindIntegrationAnchors(
    object.list = obj_rna.list,
    anchor.features = rna_features, 
    reduction = "rpca")
rna.combined <- IntegrateData(anchorset = rna.anchors)

obj[["rna_int"]] <- GetAssay(rna.combined, assay = "integrated")
DefaultAssay(obj) <- "rna_int"
obj <- ScaleData(obj, verbose = FALSE)
obj <- RunPCA(obj, reduction.name = "pca_rpca_rna")
obj_adt <- GetAssayData(object = obj, assay = "adt")
obj_adt <- CreateSeuratObject(counts = obj_adt, assay = "adt")
obj_adt@meta.data$l1 <- adt[['l1']]
obj_adt@meta.data$batch <- adt[['batch']]
obj_adt.list <- SplitObject(obj_adt, split.by = "batch")
obj_adt.list <- lapply(X = obj_adt.list, FUN = function(x) {
    x <- NormalizeData(x, normalization.method = "CLR", margin = 2)
    x <- FindVariableFeatures(x)
})

adt_features <- SelectIntegrationFeatures(object.list = obj_adt.list)
obj_adt.list <- lapply(X = obj_adt.list, FUN = function(x) {
    x <- ScaleData(x, features = adt_features, verbose = FALSE)
    x <- RunPCA(x, features = adt_features, verbose = FALSE, reduction.name = "pca")
})
adt.anchors <- FindIntegrationAnchors(
    object.list = obj_adt.list,
    anchor.features = adt_features,
    reduction = "rpca")
adt.combined <- IntegrateData(anchorset = adt.anchors)

obj[["adt_int"]] <- GetAssay(adt.combined, assay = "integrated")
DefaultAssay(obj) <- "adt_int"
obj <- ScaleData(obj, verbose = FALSE)
obj <- RunPCA(obj, reduction.name = "pca_rpca_adt")
# wnn
obj <- FindMultiModalNeighbors(obj, list("pca_rpca_rna", "pca_rpca_adt"),
                                    list(1:K, 1:K))
# save connectivity matrices for benchmarking
connectivities <- obj$wsnn
diag(connectivities) <- 0
mkdir(pj(output_dir,'step_1'), remove_old = F)
invisible(writeMM(connectivities, pj(output_dir, 'step_1', "connectivities.mtx")))
obj <- RunUMAP(obj, nn.name = "weighted.nn", reduction.name = "umap")
SaveH5Seurat(obj, pj(output_dir, 'step_1', "obj.h5seurat"), overwrite = TRUE)
# obj <- LoadH5Seurat(pj(output_dir, 'step_1', "obj.h5seurat"), assays = "ADT", reductions = "umap")
dim_plot(obj, w = l, h = l, reduction = "umap",
    group.by = "l1", label = F,
    repel = T, label.size = 4, pt.size = 0.5, cols = NULL,
    title = 'rpca', legend = F,
    save_path = pj(output_dir, 'step_1', paste0('rpca_', "celltype")))
dim_plot(obj, w = l, h = l, reduction = "umap",
    group.by = "batch", label = F,
    repel = T, label.size = 4, pt.size = 0.5, cols = NULL,
    title = 'rpca', legend = F,
    save_path = pj(output_dir, 'step_1', paste0('rpca_', "batch")))
# Out:
# Scaling features for provided objects
#
# Computing within dataset neighborhoods
#
# Finding all pairwise anchors
#
# Projecting new data onto SVD
#
# Projecting new data onto SVD
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 1289 anchors
#
# Merging dataset 2 into 1
#
# Extracting anchors for merged samples
#
# Finding integration vectors
#
# Finding integration vector weights
#
# Integrating data
#
# PC_ 1
# Positive:  RPS27, RPS12, RPL13, CD3D, CD3E, TRBC2, IL7R, MALAT1, CD3G, IL32
# 	   LTB, ARL4C, CD2, TRAC, LCK, CLEC2D, SYNE2, CD247, TRBC1, LINC00861
# 	   TCF7, CD7, ISG20, GZMM, LBH, SKAP1, SPOCK2, STK17A, CD52, BCL11B
# Negative:  FCN1, MNDA, CSTA, SERPINA1, CST3, CYBB, CLEC12A, FGL2, VCAN, LYZ
# 	   NCF2, CFD, CD14, MPEG1, S100A9, MS4A6A, GRN, S100A8, CD68, SPI1
# 	   TYMP, TNFAIP2, IGSF6, LST1, CFP, CLEC7A, AIF1, S100A12, KCTD12, CD36
# PC_ 2
# Positive:  NKG7, KLRD1, GNLY, PRF1, GZMB, GZMA, CST7, FGFBP2, KLRF1, CTSW
# 	   HOPX, SPON2, GZMH, CCL4, CCL5, FCGR3A, ADGRG1, TRDC, CX3CR1, TTC38
# 	   CLIC3, PTGDR, PLEK, TBX21, C1orf21, IL2RB, MYBL1, SAMD3, MATK, S1PR5
# Negative:  CCR7, LTB, RPL13, RPS12, RCAN3, CD27, LEF1, MAL, LRRN3, TRABD2A
# 	   IL7R, TCF7, IL6ST, PIK3IP1, MYC, RGCC, NOSIP, DGKA, OXNAD1, TSHZ2
# 	   CD79A, RPS27, RGS10, FAM102A, BIRC3, LINC00926, MS4A1, TRAT1, CD3G, FHIT
# PC_ 3
# Positive:  S100A6, CD3D, TRAC, CD3G, IL7R, CD3E, BCL11B, IL32, TCF7, NOSIP
# 	   VIM, MAL, RGS10, LEF1, CD27, CD8B, CD14, CAMK4, CD48, OXNAD1
# 	   RBP7, S100A4, CSF3R, RGS2, S100A11, MEGF9, CDA, FBXO48, LINC01550, PIK3IP1
# Negative:  TCL1A, MS4A1, BANK1, IGHD, CD79A, IGHM, BCL11A, BCL7A, LINC00926, SPIB
# 	   TSPAN13, TNFRSF13C, FCRL1, BLNK, FAM30A, VPREB3, IRF8, CD79B, TCF4, AFF3
# 	   HLA-DOA, FAM129C, HLA-DQA1, ADAM28, POU2AF1, PCDH9, PKIG, PAX5, FCRLA, HLA-DOB
# PC_ 4
# Positive:  MS4A1, TCL1A, CD79A, LINC00926, IGHD, BANK1, TNFRSF13C, FCRL1, IGHM, HLA-DOB
# 	   VPREB3, PAX5, FCRLA, CD24, POU2AF1, ARHGAP24, CD72, CD79B, CTSS, FCRL5
# 	   CD52, S100A12, S100A8, CD19, CD40, FCER2, S100A9, CD22, NCF1, MARCH1
# Negative:  CD34, FCER1A, CDK6, NREP, FABP5, AC084033.3, RAB13, SOX4, FLT3, IL18
# 	   ANKRD28, IGF2BP2, STMN1, TSC22D1, BEX4, ETS2, SEPT11, ATP8B4, DST, KIT
# 	   FHL1, ALCAM, LMNA, CD109, ATP1B1, ZNRF1, GSN, ENHO, GNA15, BEX2
# PC_ 5
# Positive:  CAVIN2, PF4, TUBB1, GNG11, PPBP, ITGA2B, ACRBP, PRKAR2B, CLEC1B, C2orf88
# 	   TSC22D1, MAP3K7CL, HIST1H2AC, MMD, MGLL, MTURN, NRGN, SNCA, CD9, TSPAN33
# 	   NEXN, CA2, ABCC3, TMEM140, ITGB3, TNFSF4, PTGS1, GP1BA, PGRMC1, DMTN
# Negative:  MALAT1, RPL13, RPS12, JUN, NAIP, PTPRC, NCF1, RPS27, CLEC2D, ITGAM
# 	   CDC42EP3, QPCT, VNN2, ASGR1, SYNE2, CD14, RNASE6, CLEC4E, CYP1B1, RAB11FIP1
# 	   STK17A, S100A12, FAM198B, CXCR4, IL17RA, ENTPD1, CD163, CEBPD, CRISPLD2, KCTD12
#
# Scaling features for provided objects
#
# Computing within dataset neighborhoods
#
# Finding all pairwise anchors
#
# Projecting new data onto SVD
#
# Projecting new data onto SVD
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 1790 anchors
#
# Merging dataset 2 into 1
#
# Extracting anchors for merged samples
#
# Finding integration vectors
#
# Finding integration vector weights
#
# Integrating data
#
# Warning message:
# "Cannot add objects with duplicate keys (offending key: integrated_), setting key to 'adt_int_'"
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from adt_int_ to adtint_"
# PC_ 1
# Positive:  clec12a, cd63, cd64, cd11b.2, cd31, cd36, cd86, cd41, cd155, cd93
# 	   cd61, cd11c, cd35, cd9, cd172a, cd119, cd14, cd11b.1, cd62p, cd49b
# 	   clec1b, cd39, cd13, cd29, cd42b, cd110, cd354, cd69, cd141, cd205
# Negative:  cd2, cd3.2, cd3.1, cd127, cd27, cd45rb, tcrab, cd28, cd278, cd52
# 	   cd96, cd81, cd26.2, cd45ra, cd314, cd8a, cd8, cd73, cd99, cd307e
# 	   cd109, integrin.7, cd4.1, cd279, cd122, cd56.1, galectin.9, cd4.2, cd25, cd161
# PC_ 2
# Positive:  cd43, cd244, cd56.2, cd16, cd122, cd314, cd335, cd18, cd56.1, cd8a
# 	   cd337, cd158b, cd8, cd158e1, cd57, cd161, cd99, cd271, cd226, cd2
# 	   tigit, cd195, cd199, lox.1, cd324, cd319, cd178, cd158, cd203c, notch1
# Negative:  cd268, cd21, cd72, cd19, cd22, cd20, igd, cd196, cd275.2, igm
# 	   hla.dr, cd55, cd40, cd73, cd39, cd272, cd1c, cd200, cd52, cd79b
# 	   cd164, cd4.1, cd35, cd4.2, cd98, cd48, cd109, cd25, cd71, cd305
# PC_ 3
# Positive:  cd56.2, cd335, cd16, cd72, cd337, cd22, cd19, igd, cd56.1, cd158e1
# 	   cd21, cd244, cd158b, cd38.2, cd268, cd20, cd45ra, igm, cd38.1, cd122
# 	   cd200, cd305, cd158, cd43, cd307c.fcrl3, cd138.1, cd338, hla.dr, cd79b, cd196
# Negative:  cd4.2, cd44.1, cd4.1, cd109, cd48, cd44.2, cd28, cd127, cd3.2, cd3.1
# 	   cd45ro, cd278, cd46, cd27, cd49a, cd52, cd45.2, cd307e, cd96, tcrab
# 	   cd2, cd95, cd126, cd26.2, cd55, cd47, cd45rb, cd25, cd226, cd93
# PC_ 4
# Positive:  cd138.1, cd338, cd325, cd243, cd275.1, cd194, cd83, cd59, cd138.2, gp130
# 	   cd357, vegfr3, cd4.1, cd70, cd199, cd4.2, cd133.1, cd66b, cd140b, cd144
# 	   siglec.8, cd202b, cd319, cd324, cd252, cd68, cd142, cd126, cd223, cd294
# Negative:  cd45.2, cd314, cd49d, cd8, cd44.1, cd8a, cd43, cd44.2, cd57, cd18
# 	   cd16, cd20, cd244, cd226, cd47, cd73, cd81, integrin.7, cd69, cd195
# 	   cd46, cd48, cd268, cd45ra, cd21, cd122, cd19, cd56.2, cd102, cd29
# PC_ 5
# Positive:  cd110, cd42b, clec1b, cd226, cd49b, cd62p, cd102, cd69, cd9, cd41
# 	   cd112, cd61, gp130, cd47, cd34, cd194, cd164, cd29, cd107a, cd31
# 	   cd71, cd63, cd274, cd133.2, cd27, cd45rb, cd117, cd45ra, tslpr, cd141
# Negative:  cd18, cd45.2, cd44.1, cd11b.1, cd48, cd44.2, cd93, cd14, cd11b.2, cd95
# 	   cd11c, cd354, cd64, cd49d, cd119, cd205, cd172a, cd155, cd86, cd43
# 	   cd45ro, cd1d, cd35, clec12a, cd45.1, cd305, cd57, cd13, cd39, folate
#
# Warning message:
# "Cannot add objects with duplicate keys (offending key: PC_), setting key to 'pca_rpca_adt_'"
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from normpca_rpca_adt_ to normpcarpcaadt_"
# Warning message:
# "All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to normpcarpcaadt_"
# Calculating kernel bandwidths
#
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#
# Warning message:
# "The default method for RunUMAP has changed from calling Python UMAP via reticulate to the R-native UWOT using the cosine metric
# To use Python UMAP via reticulate, set umap.method to 'umap-learn' and metric to 'correlation'
# This message will be shown once per session"
# 03:02:05 UMAP embedding parameters a = 0.9922 b = 1.112
#
# 03:02:06 Commencing smooth kNN distance calibration using 64 threads
#
# 03:02:08 Initializing from normalized Laplacian + noise
#
# 03:02:09 Commencing optimization for 200 epochs, with 308768 positive edges
#
# 03:02:15 Optimization finished
#
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding counts for rna
#
# Adding data for rna
#
# No variable features found for rna
#
# No feature-level metadata found for rna
#
# Adding counts for adt
#
# Adding data for adt
#
# No variable features found for adt
#
# No feature-level metadata found for adt
#
# Adding data for rna_int
#
# Adding scale.data for rna_int
#
# Adding variable features for rna_int
#
# No feature-level metadata found for rna_int
#
# Adding data for adt_int
#
# Adding scale.data for adt_int
#
# Adding variable features for adt_int
#
# No feature-level metadata found for adt_int
#
# Adding cell embeddings for pca_rpca_rna
#
# Adding loadings for pca_rpca_rna
#
# No projected loadings for pca_rpca_rna
#
# Adding standard deviations for pca_rpca_rna
#
# No JackStraw data for pca_rpca_rna
#
# Adding cell embeddings for pca_rpca_adt
#
# Adding loadings for pca_rpca_adt
#
# No projected loadings for pca_rpca_adt
#
# Adding standard deviations for pca_rpca_adt
#
# No JackStraw data for pca_rpca_adt
#
# Adding cell embeddings for umap
#
# No loadings for umap
#
# No projected loadings for umap
#
# No standard deviations for umap
#
# No JackStraw data for umap

# %% [markdown]
# # for new batch

# %%
for(step in c(2:7)){
    obj <- LoadH5Seurat(paste0('/opt/data/private/xx/code/miracle2/result/comparison/wnn_full_cellmask/increamental_integration_rpca/step_', step-1,'/obj.h5seurat'))

    rna <- rna_all[, rna_all[['batch']]==paste0('p',step+1,'_0')]
    # rna@meta.data[['nCount_rna']] <- NULL
    # rna@meta.data[['nCount_adt']] <- NULL
    # rna@meta.data[['nFeature_adt']] <- NULL
    # rna@meta.data[['nFeature_rna']] <- NULL
    # rna@meta.data[['nCount_RNA']] <- NULL
    # rna@meta.data[['nFeature_RNA']] <- NULL


    adt <- GetAssayData(object = adt_all[, adt_all[['batch']]==paste0('p',step+1,'_0')], assay = "adt")
    adt <- CreateSeuratObject(counts = adt, assay = "adt")
    
    # adt@meta.data[['nCount_rna']] <- NULL
    # adt@meta.data[['nCount_adt']] <- NULL
    # adt@meta.data[['nFeature_adt']] <- NULL
    # adt@meta.data[['nFeature_rna']] <- NULL
    # adt@meta.data[['nCount_RNA']] <- NULL
    # adt@meta.data[['nFeature_RNA']] <- NULL

    rna_ref <- GetAssayData(object = obj, assay = "rna_int")
    rna_ref <- CreateSeuratObject(counts = rna_ref, assay = "rna")
    rna_ref[['l1']] <- obj[['l1']]
    rna_ref[['batch']] <- 'reference'
    # rna_ref[['nCount_RNA']] <- NULL
    # rna_ref[['nFeature_RNA']] <- NULL

    adt_ref <- GetAssayData(object = obj, assay = "adt_int")
    adt_ref <- CreateSeuratObject(counts = adt_ref, assay = "adt")
    adt_ref[['l1']] <- obj[['l1']]
    adt_ref[['batch']] <- 'reference'
    # adt_ref[['nCount_ADT']] <- NULL
    # adt_ref[['nFeature_ADT']] <- NULL

    rna <- merge(rna_ref, rna)
    adt <- merge(adt_ref, adt)

    obj <- rna
    obj[["adt"]] <- CreateAssayObject(counts = adt@assays$adt@counts)
    obj

    obj_rna <- GetAssayData(object = obj, assay = "rna")
    obj_rna <- CreateSeuratObject(counts = obj_rna, assay = "rna")
    obj_rna[['l1']] <- rna[['l1']]
    obj_rna[['batch']] <- rna[['batch']]

    obj_rna.list <- SplitObject(obj_rna, split.by = "batch")
    obj_rna.list

    obj_rna.list[[paste0('p',step+1,'_0')]] <- NormalizeData(obj_rna.list[[paste0('p',step+1,'_0')]])

    obj_rna.list <- lapply(X = obj_rna.list, FUN = function(x) {
    # x <- NormalizeData(x)
    x <- FindVariableFeatures(x, nfeatures = 5000)
    })
    rna_features <- SelectIntegrationFeatures(object.list = obj_rna.list, nfeatures = 5000)
    obj_rna.list <- lapply(X = obj_rna.list, FUN = function(x) {
        x <- ScaleData(x, features = rna_features, verbose = FALSE)
        x <- RunPCA(x, features = rna_features, verbose = FALSE, reduction.name = "pca")
    })
    rna.anchors <- FindIntegrationAnchors(
        object.list = obj_rna.list,
        anchor.features = rna_features,
        reduction = "rpca")
    rna.combined <- IntegrateData(anchorset = rna.anchors)

    obj[["rna_int"]] <- GetAssay(rna.combined, assay = "integrated")
    DefaultAssay(obj) <- "rna_int"
    obj <- ScaleData(obj, verbose = FALSE)
    obj <- RunPCA(obj, reduction.name = "pca_rpca_rna")

    obj_adt <- GetAssayData(object = obj, assay = "adt")
    obj_adt <- CreateSeuratObject(counts = obj_adt, assay = "adt")
    obj_adt[['l1']] <- obj[['l1']]
    obj_adt[['batch']]<- obj[['batch']]
    obj_adt.list <- SplitObject(obj_adt, split.by = "batch")
    obj_adt.list[[paste0('p',step+1,'_0')]] <- NormalizeData(obj_adt.list[[paste0('p',step+1,'_0')]], normalization.method = "CLR", margin = 2)
    obj_adt.list <- lapply(X = obj_adt.list, FUN = function(x) {
        # x <- NormalizeData(x, normalization.method = "CLR", margin = 2)
        x <- FindVariableFeatures(x)
    })

    adt_features <- SelectIntegrationFeatures(object.list = obj_adt.list)
    obj_adt.list <- lapply(X = obj_adt.list, FUN = function(x) {
        x <- ScaleData(x, features = adt_features, verbose = FALSE)
        x <- RunPCA(x, features = adt_features, verbose = FALSE, reduction.name = "pca")
    })
    adt.anchors <- FindIntegrationAnchors(
        object.list = obj_adt.list,
        anchor.features = adt_features,
        reduction = "rpca")
    adt.combined <- IntegrateData(anchorset = adt.anchors)

    obj[["adt_int"]] <- GetAssay(adt.combined, assay = "integrated")
    DefaultAssay(obj) <- "adt_int"
    obj <- ScaleData(obj, verbose = FALSE)
    obj <- RunPCA(obj, reduction.name = "pca_rpca_adt")
    # wnn
    obj <- FindMultiModalNeighbors(obj, list("pca_rpca_rna", "pca_rpca_adt"),
                                        list(1:K, 1:K))
    # save connectivity matrices for benchmarking
    connectivities <- obj$wsnn
    diag(connectivities) <- 0
    mkdir(pj(output_dir,paste0('step_',step)), remove_old = F)
    invisible(writeMM(connectivities, pj(output_dir, paste0('step_',step), "connectivities.mtx")))
    
    obj <- RunUMAP(obj, nn.name = "weighted.nn", reduction.name = "umap")
    SaveH5Seurat(obj, pj(output_dir, paste0('step_',step), "obj.h5seurat"), overwrite = TRUE)
    
    # obj <- LoadH5Seurat(pj(output_dir, "obj.h5seurat"), assays = "adt", reductions = "umap")

    # dim_plot(obj, w = 4, h = 4, reduction = 'umap', no_axes = T,
    #     split.by = NULL, group.by = "orig.ident", label = F, repel = T, label.size = 4, pt.size = 0.1, cols = col_4, legend = F,
    #     save_path = pj(output_dir, paste0('step_',step), paste('rpca', "merged_batch", sep = "_")))

    # dim_plot(obj, w = 4, h = 4, reduction = 'umap', no_axes = T,
    #     split.by = NULL, group.by = "l1", label = F, repel = T, label.size = 4, pt.size = 0.1, cols = col_8, legend = F,
    #     save_path = pj(output_dir, paste0('step_',step),paste('rpca', "merged_label", sep = "_")))
    }
# Out:
# Validating h5Seurat file
#
# Initializing adt with data
#
# Adding counts for adt
#
# Adding miscellaneous information for adt
#
# Initializing adt_int with data
#
# Adding scale.data for adt_int
#
# Adding variable feature information for adt_int
#
# Initializing rna with data
#
# Adding counts for rna
#
# Adding miscellaneous information for rna
#
# Initializing rna_int with data
#
# Adding scale.data for rna_int
#
# Adding variable feature information for rna_int
#
# Adding reduction pca_rpca_adt
#
# Adding cell embeddings for pca_rpca_adt
#
# Adding feature loadings for pca_rpca_adt
#
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from pca_rpca_adt_ to pcarpcaadt_"
# Warning message:
# "All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to pcarpcaadt_"
# Adding miscellaneous information for pca_rpca_adt
#
# Adding reduction umap
#
# Adding cell embeddings for umap
#
# Adding miscellaneous information for umap
#
# Adding reduction pca_rpca_rna
#
# Adding cell embeddings for pca_rpca_rna
#
# Adding feature loadings for pca_rpca_rna
#
# Adding miscellaneous information for pca_rpca_rna
#
# Adding graph wknn
#
# Adding graph wsnn
#
# Adding neighbors weighted.nn
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results
#
# Scaling features for provided objects
#
# Computing within dataset neighborhoods
#
# Finding all pairwise anchors
#
# Projecting new data onto SVD
#
# Projecting new data onto SVD
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 1645 anchors
#
# Merging dataset 2 into 1
#
# Extracting anchors for merged samples
#
# Finding integration vectors
#
# Finding integration vector weights
#
# Integrating data
#
# PC_ 1
# Positive:  FCN1, MNDA, SERPINA1, CSTA, CST3, CLEC12A, CYBB, FGL2, NCF2, LYZ
# 	   CFD, VCAN, MPEG1, S100A9, CD68, MS4A6A, SPI1, CD14, TNFAIP2, GRN
# 	   IGSF6, S100A8, TYMP, LST1, AIF1, CLEC7A, CFP, KCTD12, RETN, CPVL
# Negative:  RPS27, RPS12, RPL13, CD3E, TRBC2, MALAT1, CD3D, IL7R, IL32, ARL4C
# 	   CD2, CD3G, LTB, TRAC, CD247, SYNE2, LCK, LINC00861, TRBC1, CLEC2D
# 	   ISG20, CD7, TCF7, GZMM, SKAP1, LBH, STK17A, SPOCK2, RORA, CD52
# PC_ 2
# Positive:  NKG7, KLRD1, PRF1, GNLY, GZMB, CST7, GZMA, KLRF1, FGFBP2, SPON2
# 	   CTSW, HOPX, GZMH, ADGRG1, TRDC, FCGR3A, CCL4, CX3CR1, TTC38, PTGDR
# 	   CLIC3, CCL5, IL2RB, TBX21, PLEK, C1orf21, MATK, CD63, SRGN, MYBL1
# Negative:  LTB, RPL13, RPS12, CCR7, CD79A, RCAN3, IL7R, MS4A1, BIRC3, TCL1A
# 	   BANK1, TRABD2A, TNFRSF13C, MAL, IGHM, LINC00926, CD27, TCF7, LEF1, MYC
# 	   LRRN3, IGHD, BCL7A, RPS27, RGCC, IL6ST, DGKA, P2RX5, FCRL1, SPIB
# PC_ 3
# Positive:  TRAC, CD3D, CD3G, IL7R, BCL11B, TCF7, CD3E, MAL, NOSIP, RGS10
# 	   CD27, LEF1, CAMK4, IL32, OXNAD1, S100A6, CD8B, RCAN3, VIM, PIK3IP1
# 	   TRAT1, RGCC, LINC01550, TNFAIP3, SERINC5, ITK, CCR7, LAT, AL365361.1, LRRN3
# Negative:  MS4A1, TCL1A, BANK1, CD79A, IGHD, IGHM, LINC00926, TNFRSF13C, SPIB, FCRL1
# 	   POU2AF1, CD79B, BCL7A, BLNK, VPREB3, IRF8, BCL11A, HLA-DOB, COBLL1, TSPAN13
# 	   FAM30A, PPP1R14A, HLA-DOA, CD22, FCRLA, AFF3, HLA-DPB1, P2RX5, CD72, FAM129C
# PC_ 4
# Positive:  S100A12, S100A8, MS4A1, S100A9, VNN2, CD79A, LINC00926, RBP7, BANK1, TCL1A
# 	   IGHD, NCF1, TNFRSF13C, VCAN, CTSS, CD14, FCRL1, IGHM, ARHGAP24, VPREB3
# 	   CYP1B1, LYZ, HLA-DOB, STEAP4, RGS2, S100A6, CLEC4E, FTL, POU2AF1, LRRK2
# Negative:  FCER1A, PLD4, CD34, FABP5, ENHO, CDK6, NREP, CLEC10A, FLT3, IL3RA
# 	   MGLL, AC084033.3, LMNA, SEPT11, BATF3, ITM2C, STMN1, ALCAM, PPP1R14B, ADA
# 	   ETS2, ANKRD28, IL18, CDKN1C, RAB13, RAB34, CKAP2, TSC22D1, DST, GSN
# PC_ 5
# Positive:  S100A12, RNASE6, VCAN, QPCT, MGST1, CD163, RNASE2, CD14, CSF3R, CCR2
# 	   NAIP, MS4A6A, TFEC, CREB5, CD36, CLEC4E, STEAP4, PTAFR, CRISPLD2, CYP1B1
# 	   SOX4, CLEC4D, MCEMP1, AL034397.3, SIRPA, CD99, CAPG, ASGR2, LMNB1, CEBPD
# Negative:  CDKN1C, TCF7L2, CKB, SIGLEC10, HES4, FCGR3A, BATF3, SMIM25, FCGR3B, HMOX1
# 	   TNFRSF8, IFITM3, RRAS, ZNF703, NEURL1, CTSL, RHOC, MYOF, FAM110A, MS4A7
# 	   CAMK1, MAFB, MTSS1, LINC02432, TMSB4X, ICAM4, CDH23, CD79B, BCL2A1, CD52
#
# Scaling features for provided objects
#
# Computing within dataset neighborhoods
#
# Finding all pairwise anchors
#
# Projecting new data onto SVD
#
# Projecting new data onto SVD
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 2414 anchors
#
# Merging dataset 2 into 1
#
# Extracting anchors for merged samples
#
# Finding integration vectors
#
# Finding integration vector weights
#
# Integrating data
#
# Warning message:
# "Cannot add objects with duplicate keys (offending key: integrated_), setting key to 'adt_int_'"
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from adt_int_ to adtint_"
# PC_ 1
# Positive:  cd2, cd3.2, cd3.1, cd127, cd27, cd28, tcrab, cd45rb, cd278, cd52
# 	   cd81, cd96, cd26.2, cd307e, cd109, cd45ra, cd99, cd4.1, cd8a, cd314
# 	   cd8, cd73, cd4.2, cd279, integrin.7, cd56.1, cd122, cd25, galectin.9, cd161
# Negative:  clec12a, cd63, cd31, cd64, cd36, cd86, cd41, cd11b.2, cd155, cd61
# 	   cd93, cd11c, cd9, cd172a, cd35, cd119, cd62p, cd14, cd11b.1, cd49b
# 	   clec1b, cd39, cd13, cd42b, cd29, cd110, cd141, cd354, cd69, cd55
# PC_ 2
# Positive:  cd268, cd21, cd20, cd19, cd72, cd22, igd, cd196, cd275.2, cd55
# 	   cd52, cd44.2, cd4.1, cd4.2, cd39, hla.dr, igm, cd109, cd73, cd1c
# 	   cd40, cd48, cd272, cd44.1, cd164, cd35, cd25, cd307e, cd28, cd79b
# Negative:  cd244, cd43, cd56.2, cd16, cd122, cd335, cd56.1, cd314, cd337, cd158b
# 	   cd8a, cd158e1, cd18, cd8, cd161, cd57, cd271, cd38.1, tigit, cd38.2
# 	   cd158, cd99, cd45ra, cd324, cx3cr1, cd325, lox.1, cd319, cd199, notch1
# PC_ 3
# Positive:  cd4.2, cd4.1, cd109, cd45ro, cd3.2, cd127, cd44.1, cd3.1, cd28, cd44.2
# 	   cd48, cd49a, cd278, cd2, cd46, cd27, cd307e, cd96, tcrab, cd95
# 	   galectin.9, cd226, cd99, cd26.2, cd45.2, cd126, cd52, cd29, cd279, cd62p
# Negative:  cd72, cd22, cd19, cd21, igd, cd268, cd20, igm, cd45ra, cd56.2
# 	   cd337, cd196, cd305, cd38.2, cd335, cd79b, cd16, hla.dr, cd200, cd38.1
# 	   cd1c, cd40, cd158e1, cd272, cd158b, cd73, cd24, cd56.1, cd275.2, cd307c.fcrl3
# PC_ 4
# Positive:  cd45.2, cd314, cd49d, cd47, cd8, cd44.1, cd226, cd8a, cd44.2, cd69
# 	   cd46, cd43, cd73, cd16, cd48, cd57, integrin.7, cd18, cd81, cd244
# 	   cd102, cd195, cd20, cd45ra, cd29, cd161, cd71, cd122, cd62p, cd2
# Negative:  cd338, cd138.1, cd243, cd325, cd275.1, cd83, cd138.2, cd59, vegfr3, cd357
# 	   cd194, cd199, cd70, gp130, cd66b, cd319, cd202b, cd68, cd140b, cd133.1
# 	   siglec.8, cd144, cd324, cd252, cd142, cd294, cd158f, cd4.1, cd4.2, cd307d
# PC_ 5
# Positive:  cd18, cd45.2, cd11b.1, cd48, cd44.1, cd93, cd14, cd11b.2, cd44.2, cd354
# 	   cd64, cd205, cd155, cd95, cd35, cd11c, cd119, cd86, clec12a, cd1d
# 	   cd172a, cd305, cd57, cd38.1, folate, cd45.1, cd49a, cd45ro, cd43, cd13
# Negative:  cd42b, cd110, clec1b, cd226, cd49b, cd62p, cd102, cd69, cd9, cd41
# 	   cd112, cd61, cd47, cd194, gp130, cd34, cd107a, cd29, cd164, cd63
# 	   cd274, cd31, cd133.2, cd71, cd141, cd123, cd27, tslpr, cd117, cd45rb
#
# Warning message:
# "Cannot add objects with duplicate keys (offending key: PC_), setting key to 'pca_rpca_adt_'"
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from normpca_rpca_adt_ to normpcarpcaadt_"
# Warning message:
# "All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to normpcarpcaadt_"
# Calculating kernel bandwidths
#
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#
# 03:11:07 UMAP embedding parameters a = 0.9922 b = 1.112
#
# 03:11:08 Commencing smooth kNN distance calibration using 64 threads
#
# 03:11:10 Initializing from normalized Laplacian + noise
#
# 03:11:11 Commencing optimization for 200 epochs, with 436016 positive edges
#
# 03:11:20 Optimization finished
#
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding counts for rna
#
# Adding data for rna
#
# No variable features found for rna
#
# No feature-level metadata found for rna
#
# Adding counts for adt
#
# Adding data for adt
#
# No variable features found for adt
#
# No feature-level metadata found for adt
#
# Adding data for rna_int
#
# Adding scale.data for rna_int
#
# Adding variable features for rna_int
#
# No feature-level metadata found for rna_int
#
# Adding data for adt_int
#
# Adding scale.data for adt_int
#
# Adding variable features for adt_int
#
# No feature-level metadata found for adt_int
#
# Adding cell embeddings for pca_rpca_rna
#
# Adding loadings for pca_rpca_rna
#
# No projected loadings for pca_rpca_rna
#
# Adding standard deviations for pca_rpca_rna
#
# No JackStraw data for pca_rpca_rna
#
# Adding cell embeddings for pca_rpca_adt
#
# Adding loadings for pca_rpca_adt
#
# No projected loadings for pca_rpca_adt
#
# Adding standard deviations for pca_rpca_adt
#
# No JackStraw data for pca_rpca_adt
#
# Adding cell embeddings for umap
#
# No loadings for umap
#
# No projected loadings for umap
#
# No standard deviations for umap
#
# No JackStraw data for umap
#
# Validating h5Seurat file
#
# Initializing adt with data
#
# Adding counts for adt
#
# Adding miscellaneous information for adt
#
# Initializing adt_int with data
#
# Adding scale.data for adt_int
#
# Adding variable feature information for adt_int
#
# Initializing rna with data
#
# Adding counts for rna
#
# Adding miscellaneous information for rna
#
# Initializing rna_int with data
#
# Adding scale.data for rna_int
#
# Adding variable feature information for rna_int
#
# Adding reduction pca_rpca_adt
#
# Adding cell embeddings for pca_rpca_adt
#
# Adding feature loadings for pca_rpca_adt
#
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from pca_rpca_adt_ to pcarpcaadt_"
# Warning message:
# "All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to pcarpcaadt_"
# Adding miscellaneous information for pca_rpca_adt
#
# Adding reduction umap
#
# Adding cell embeddings for umap
#
# Adding miscellaneous information for umap
#
# Adding reduction pca_rpca_rna
#
# Adding cell embeddings for pca_rpca_rna
#
# Adding feature loadings for pca_rpca_rna
#
# Adding miscellaneous information for pca_rpca_rna
#
# Adding graph wknn
#
# Adding graph wsnn
#
# Adding neighbors weighted.nn
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results
#
# Scaling features for provided objects
#
# Computing within dataset neighborhoods
#
# Finding all pairwise anchors
#
# Projecting new data onto SVD
#
# Projecting new data onto SVD
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 1874 anchors
#
# Merging dataset 2 into 1
#
# Extracting anchors for merged samples
#
# Finding integration vectors
#
# Finding integration vector weights
#
# Integrating data
#
# PC_ 1
# Positive:  RPS27, RPS12, RPL13, CD3E, CD3D, IL7R, MALAT1, TRBC2, LTB, IL32
# 	   CD3G, CD2, ARL4C, TRAC, LCK, LINC00861, TRBC1, SYNE2, CD247, ISG20
# 	   TCF7, CLEC2D, CD7, SKAP1, SPOCK2, GZMM, LBH, STK17A, BCL11B, CD52
# Negative:  FCN1, MNDA, SERPINA1, CSTA, CST3, FGL2, CLEC12A, CYBB, VCAN, LYZ
# 	   CFD, NCF2, MPEG1, S100A9, CD14, MS4A6A, S100A8, CD68, GRN, SPI1
# 	   TNFAIP2, CLEC7A, IGSF6, CFP, TYMP, AIF1, LST1, KCTD12, RETN, FTL
# PC_ 2
# Positive:  MS4A1, CD79A, BANK1, TCL1A, TNFRSF13C, LINC00926, IGHM, BCL7A, IGHD, VPREB3
# 	   SPIB, LTB, FCRL1, POU2AF1, P2RX5, HLA-DOB, BLNK, HLA-DOA, BIRC3, BCL11A
# 	   AFF3, FCRL5, PPP1R14A, RALGPS2, GNG7, RPL13, CD79B, COBLL1, PKIG, CD24
# Negative:  NKG7, KLRD1, PRF1, GZMA, CST7, GNLY, GZMB, KLRF1, FGFBP2, SPON2
# 	   HOPX, CTSW, GZMH, ADGRG1, TRDC, CCL4, FCGR3A, CCL5, TTC38, PTGDR
# 	   CLIC3, CX3CR1, IL2RB, MYBL1, C1orf21, TBX21, MATK, SAMD3, SRGN, ABHD17A
# PC_ 3
# Positive:  MS4A1, BANK1, TCL1A, CD79A, TNFRSF13C, LINC00926, CD79B, IGHM, SPIB, POU2AF1
# 	   IGHD, CXXC5, GZMB, BLNK, VPREB3, FCRL1, HLA-DOB, IRF8, HLA-DPB1, GNLY
# 	   BCL7A, BCL11A, SPON2, PPP1R14A, HLA-DOA, KLRF1, FGFBP2, TSPAN13, KLRD1, AFF3
# Negative:  TRAC, IL7R, CD3D, CD3G, MAL, TCF7, LEF1, NOSIP, BCL11B, RGS10
# 	   CD3E, CD27, CAMK4, RCAN3, OXNAD1, RGCC, VIM, CCR7, LRRN3, PIK3IP1
# 	   RPS12, CD8B, TRAT1, RPL13, IL32, LINC01550, SERINC5, LDLRAP1, RETREG1, ITK
# PC_ 4
# Positive:  S100A12, S100A8, S100A9, VNN2, RBP7, VCAN, NCF1, CD14, CYP1B1, MS4A1
# 	   RGS2, STEAP4, CLEC4D, CTSS, LYZ, CLEC4E, LRRK2, CMTM2, AQP9, ITGAM
# 	   RETN, MCEMP1, MNDA, LINC00926, QPCT, MARC1, ARHGAP24, TCL1A, CD79A, CDA
# Negative:  FCER1A, PLD4, BATF3, CDKN1C, ENHO, FABP5, MGLL, CLEC10A, ADA, CDK6
# 	   LMNA, IL3RA, HLA-DQA1, CD34, FLT3, RHOC, MALAT1, PPP1R14B, CKB, RAB34
# 	   CKAP2, ETS2, FAM110A, NREP, SEPT11, ITGA4, IFITM3, CDK2AP1, SPINT2, PID1
# PC_ 5
# Positive:  S100A12, RNASE6, MGST1, RNASE2, CD163, CCR2, QPCT, VCAN, NAIP, CSF3R
# 	   TFEC, CD14, CREB5, LMNB1, MS4A6A, IL18, SOX4, CRISPLD2, PTAFR, CYP1B1
# 	   CLEC4E, STEAP4, CRTAP, CD36, SIRPA, CAPG, CD99, MCEMP1, C9orf139, NREP
# Negative:  CDKN1C, CKB, TCF7L2, FCGR3A, HES4, SIGLEC10, BATF3, FCGR3B, SMIM25, TNFRSF8
# 	   IFITM3, HMOX1, RRAS, NEURL1, ZNF703, CTSL, FAM110A, TMSB4X, MYOF, RHOC
# 	   LINC02432, MS4A7, CAMK1, MTSS1, MAFB, MGLL, FTH1, ICAM4, CDH23, PPBP
#
# Scaling features for provided objects
#
# Computing within dataset neighborhoods
#
# Finding all pairwise anchors
#
# Projecting new data onto SVD
#
# Projecting new data onto SVD
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 3049 anchors
#
# Merging dataset 2 into 1
#
# Extracting anchors for merged samples
#
# Finding integration vectors
#
# Finding integration vector weights
#
# Integrating data
#
# Warning message:
# "Cannot add objects with duplicate keys (offending key: integrated_), setting key to 'adt_int_'"
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from adt_int_ to adtint_"
# PC_ 1
# Positive:  cd2, cd3.2, cd3.1, cd127, cd27, cd28, tcrab, cd45rb, cd278, cd52
# 	   cd96, cd81, cd26.2, cd307e, cd109, cd4.1, cd99, cd45ra, cd8a, cd8
# 	   cd4.2, cd314, cd73, cd279, integrin.7, cd25, cd56.1, galectin.9, cd122, cd161
# Negative:  clec12a, cd63, cd31, cd64, cd11b.2, cd86, cd36, cd41, cd155, cd93
# 	   cd61, cd11c, cd9, cd172a, cd35, cd119, cd11b.1, cd14, cd62p, cd49b
# 	   clec1b, cd39, cd13, cd42b, cd110, cd29, cd354, cd141, cd55, cd305
# PC_ 2
# Positive:  cd18, cd43, cd2, cd99, cd244, cd226, cd8a, cd122, cd45ro, cd8
# 	   cd314, cd96, galectin.9, cd95, cd161, cd279, cd3.2, cd3.1, cd195, cd62p
# 	   cd69, cd16, cd56.1, cd56.2, cd29, tcrab, cd110, cd140b, cd199, cd57
# Negative:  cd22, cd19, cd72, cd21, cd268, cd20, igd, cd196, igm, cd275.2
# 	   cd1c, hla.dr, cd79b, cd40, cd73, cd272, cd39, cd200, cd164, cd305
# 	   cd24, cd35, cd55, cd98, cd71, cd185, cd45ra, integrin.7, cd171, cd52
# PC_ 3
# Positive:  cd56.2, cd16, cd335, cd244, cd337, cd56.1, cd122, cd43, cd158b, cd158e1
# 	   cd314, cd45ra, cd38.2, cd38.1, cd158, cd8a, cd138.1, cd8, cd57, cd271
# 	   tigit, cd307c.fcrl3, cd161, cd325, cx3cr1, cd319, cd357, cd275.1, cd305, siglec.8
# Negative:  cd4.2, cd4.1, cd109, cd44.2, cd44.1, cd48, cd28, cd127, cd45ro, cd52
# 	   cd3.2, cd307e, cd3.1, cd55, cd46, cd27, cd126, cd278, cd49a, cd25
# 	   cd45.2, cd47, tcrab, cd95, cd205, cd209, cd26.2, cd96, gp130, cd45rb
# PC_ 4
# Positive:  cd45.2, cd314, cd49d, cd8, cd47, cd44.1, cd8a, cd226, cd69, cd16
# 	   cd43, cd44.2, cd73, cd46, cd57, cd244, cd48, integrin.7, cd102, cd18
# 	   cd81, cd161, cd195, cd71, cd29, cd20, cd122, cd45ra, cd335, cd62p
# Negative:  cd338, cd138.1, cd325, cd243, cd275.1, cd138.2, cd59, cd83, cd357, cd194
# 	   vegfr3, cd199, gp130, cd66b, cd70, siglec.8, cd140b, cd202b, cd68, cd133.1
# 	   cd319, cd4.1, cd324, cd144, cd4.2, cd252, cd126, cd158f, cd294, cd142
# PC_ 5
# Positive:  cd18, cd45.2, cd48, cd44.1, cd11b.1, cd93, cd14, cd44.2, cd11b.2, cd205
# 	   cd354, cd95, cd64, cd155, cd35, cd11c, cd119, cd57, cd86, cd305
# 	   clec12a, cd172a, cd1d, cd43, cd45ro, cd38.1, folate, cd45.1, cd39, cd49d
# Negative:  cd42b, cd110, clec1b, cd226, cd49b, cd62p, cd102, cd9, cd41, cd69
# 	   cd61, gp130, cd47, cd194, cd112, cd34, cd107a, cd29, cd164, cd63
# 	   cd31, cd274, cd133.2, cd141, cd71, cd27, cd45rb, tslpr, cd138.1, cd123
#
# Warning message:
# "Cannot add objects with duplicate keys (offending key: PC_), setting key to 'pca_rpca_adt_'"
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from normpca_rpca_adt_ to normpcarpcaadt_"
# Warning message:
# "All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to normpcarpcaadt_"
# Calculating kernel bandwidths
#
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#
# 03:24:39 UMAP embedding parameters a = 0.9922 b = 1.112
#
# 03:24:41 Commencing smooth kNN distance calibration using 64 threads
#
# 03:24:43 Initializing from normalized Laplacian + noise
#
# 03:24:44 Commencing optimization for 200 epochs, with 599494 positive edges
#
# 03:24:56 Optimization finished
#
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding counts for rna
#
# Adding data for rna
#
# No variable features found for rna
#
# No feature-level metadata found for rna
#
# Adding counts for adt
#
# Adding data for adt
#
# No variable features found for adt
#
# No feature-level metadata found for adt
#
# Adding data for rna_int
#
# Adding scale.data for rna_int
#
# Adding variable features for rna_int
#
# No feature-level metadata found for rna_int
#
# Adding data for adt_int
#
# Adding scale.data for adt_int
#
# Adding variable features for adt_int
#
# No feature-level metadata found for adt_int
#
# Adding cell embeddings for pca_rpca_rna
#
# Adding loadings for pca_rpca_rna
#
# No projected loadings for pca_rpca_rna
#
# Adding standard deviations for pca_rpca_rna
#
# No JackStraw data for pca_rpca_rna
#
# Adding cell embeddings for pca_rpca_adt
#
# Adding loadings for pca_rpca_adt
#
# No projected loadings for pca_rpca_adt
#
# Adding standard deviations for pca_rpca_adt
#
# No JackStraw data for pca_rpca_adt
#
# Adding cell embeddings for umap
#
# No loadings for umap
#
# No projected loadings for umap
#
# No standard deviations for umap
#
# No JackStraw data for umap
#
# Validating h5Seurat file
#
# Initializing adt with data
#
# Adding counts for adt
#
# Adding miscellaneous information for adt
#
# Initializing adt_int with data
#
# Adding scale.data for adt_int
#
# Adding variable feature information for adt_int
#
# Initializing rna with data
#
# Adding counts for rna
#
# Adding miscellaneous information for rna
#
# Initializing rna_int with data
#
# Adding scale.data for rna_int
#
# Adding variable feature information for rna_int
#
# Adding reduction pca_rpca_adt
#
# Adding cell embeddings for pca_rpca_adt
#
# Adding feature loadings for pca_rpca_adt
#
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from pca_rpca_adt_ to pcarpcaadt_"
# Warning message:
# "All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to pcarpcaadt_"
# Adding miscellaneous information for pca_rpca_adt
#
# Adding reduction umap
#
# Adding cell embeddings for umap
#
# Adding miscellaneous information for umap
#
# Adding reduction pca_rpca_rna
#
# Adding cell embeddings for pca_rpca_rna
#
# Adding feature loadings for pca_rpca_rna
#
# Adding miscellaneous information for pca_rpca_rna
#
# Adding graph wknn
#
# Adding graph wsnn
#
# Adding neighbors weighted.nn
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results
#
# Warning message in eval(predvars, data, env):
# "NaNs produced"
# Warning message in hvf.info$variance.expected[not.const] <- 10^fit$fitted:
# "number of items to replace is not a multiple of replacement length"
# Scaling features for provided objects
#
# Computing within dataset neighborhoods
#
# Finding all pairwise anchors
#
# Projecting new data onto SVD
#
# Projecting new data onto SVD
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 1368 anchors
#
# Merging dataset 2 into 1
#
# Extracting anchors for merged samples
#
# Finding integration vectors
#
# Finding integration vector weights
#
# Integrating data
#
# PC_ 1
# Positive:  RPS27, RPS12, RPL13, CD3E, CD3D, TRBC2, IL7R, IL32, MALAT1, LTB
# 	   ARL4C, CD3G, CD2, TRAC, LCK, CD247, SYNE2, LINC00861, ISG20, TRBC1
# 	   CLEC2D, CD7, TCF7, SKAP1, GZMM, SPOCK2, LBH, STK17A, CD52, BCL11B
# Negative:  FCN1, MNDA, SERPINA1, CSTA, CST3, CLEC12A, FGL2, LYZ, CYBB, VCAN
# 	   CFD, NCF2, S100A9, MPEG1, CD14, MS4A6A, S100A8, CD68, SPI1, IGSF6
# 	   CFP, TNFAIP2, GRN, CLEC7A, TYMP, RETN, KCTD12, LST1, AIF1, FTL
# PC_ 2
# Positive:  NKG7, KLRD1, PRF1, GZMA, CST7, GNLY, FGFBP2, GZMB, KLRF1, HOPX
# 	   GZMH, CTSW, SPON2, ADGRG1, FCGR3A, CCL5, CCL4, TRDC, CX3CR1, SRGN
# 	   TTC38, PTGDR, CLIC3, S100A4, ABHD17A, MYBL1, CD63, IL2RB, GZMM, ID2
# Negative:  MS4A1, CD79A, BANK1, TCL1A, TNFRSF13C, IGHM, LINC00926, BCL7A, BLNK, VPREB3
# 	   IGHD, FCRL1, P2RX5, SPIB, HLA-DOB, POU2AF1, BCL11A, CD79B, HLA-DOA, AFF3
# 	   RALGPS2, JCHAIN, COBLL1, PPP1R14A, GNG7, FCRL5, IRF8, SWAP70, FAM129C, TSPAN13
# PC_ 3
# Positive:  GZMB, GNLY, FGFBP2, KLRD1, SPON2, KLRF1, CST7, PRF1, NKG7, MS4A1
# 	   FCGR3A, GZMA, CXXC5, ADGRG1, CTSW, BANK1, GZMH, CLIC3, PLEK, TCL1A
# 	   HOPX, CCL4, CD79A, CX3CR1, PTGDR, TRDC, CD79B, TTC38, TNFRSF13C, CCL5
# Negative:  IL7R, MAL, TCF7, CD3G, CD3D, LEF1, TRAC, NOSIP, CD27, RCAN3
# 	   CCR7, RGS10, BCL11B, CD3E, OXNAD1, RPS12, CAMK4, RGCC, LRRN3, RPL13
# 	   PIK3IP1, VIM, TRAT1, LTB, CD8B, LINC01550, RETREG1, SERINC5, LDLRAP1, FAM102A
# PC_ 4
# Positive:  TUBB1, PF4, PPBP, ACRBP, CAVIN2, GNG11, ITGA2B, NRGN, S100A12, S100A8
# 	   S100A9, C2orf88, PRKAR2B, CLEC1B, HIST1H2AC, FTL, VCAN, RGS18, RBP7, MMD
# 	   CTSS, MAP3K7CL, LYZ, CCL5, FTH1, CCL3L1, TMSB4X, ABCC3, VNN2, NCF1
# Negative:  MALAT1, FCER1A, PLD4, PPP1R14B, FABP5, CLEC10A, ENHO, FLT3, IL3RA, ITM2C
# 	   SERPINF1, CDK6, STMN1, RAB34, LILRB4, NREP, DST, SEPT11, RPL13, ADA
# 	   ALCAM, IL18, CLEC4C, BATF3, RHOC, TCF4, CKAP2, RUFY3, CD1C, ETS2
# PC_ 5
# Positive:  MALAT1, VNN2, RBP7, S100A12, CD14, CYP1B1, PTPRC, CLEC4E, LRRK2, CDC42EP3
# 	   STEAP4, ITGAM, CLEC4D, QPCT, FPR1, FOLR3, NCF1, CDA, JUN, ASGR1
# 	   RETN, MCEMP1, CD93, S100A8, FAM198B, RGS2, NAIP, AQP9, GCA, IRAK3
# Negative:  CAVIN2, TUBB1, GNG11, PF4, PPBP, ACRBP, PRKAR2B, ITGA2B, TSC22D1, C2orf88
# 	   MAP3K7CL, CLEC1B, MTURN, MMD, HIST1H2AC, SNCA, ABCC3, NRGN, TSPAN33, DAB2
# 	   TMEM140, PTGS1, MGLL, CA2, PGRMC1, RUFY1, CD9, MARCH2, GP1BA, F13A1
#
# Scaling features for provided objects
#
# Computing within dataset neighborhoods
#
# Finding all pairwise anchors
#
# Projecting new data onto SVD
#
# Projecting new data onto SVD
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 1676 anchors
#
# Merging dataset 2 into 1
#
# Extracting anchors for merged samples
#
# Finding integration vectors
#
# Finding integration vector weights
#
# Integrating data
#
# Warning message:
# "Cannot add objects with duplicate keys (offending key: integrated_), setting key to 'adt_int_'"
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from adt_int_ to adtint_"
# PC_ 1
# Positive:  cd2, cd3.2, cd3.1, cd127, cd27, cd28, tcrab, cd45rb, cd278, cd52
# 	   cd96, cd81, cd26.2, cd307e, cd109, cd4.1, cd45ra, cd99, cd8, cd8a
# 	   cd314, cd4.2, cd73, cd279, integrin.7, cd25, galectin.9, cd56.1, cd48, cd161
# Negative:  clec12a, cd63, cd31, cd64, cd36, cd86, cd41, cd11b.2, cd155, cd93
# 	   cd61, cd9, cd11c, cd172a, cd119, cd35, cd11b.1, cd62p, cd14, cd49b
# 	   clec1b, cd13, cd39, cd42b, cd29, cd110, cd141, cd354, cd69, cd55
# PC_ 2
# Positive:  cd43, cd18, cd244, cd122, cd314, cd8a, cd2, cd99, cd56.2, cd16
# 	   cd8, cd226, cd56.1, cd335, cd57, cd161, galectin.9, cd337, cd271, cd96
# 	   cd158b, cd140b, cd324, cd69, lox.1, cd199, cd45ro, cd110, cd62p, cd195
# Negative:  cd19, cd22, cd72, cd268, cd21, cd20, igd, cd196, cd275.2, igm
# 	   hla.dr, cd1c, cd39, cd73, cd272, cd40, cd79b, cd200, cd164, cd55
# 	   cd35, cd305, cd24, cd98, cd71, cd52, cd185, cd25, cd171, cd205
# PC_ 3
# Positive:  cd4.2, cd4.1, cd109, cd44.2, cd44.1, cd28, cd127, cd45ro, cd3.2, cd48
# 	   cd3.1, cd307e, cd27, cd278, cd49a, cd52, cd55, cd46, cd126, cd25
# 	   tcrab, cd95, cd96, cd26.2, gp130, cd47, cd45rb, cd209, cd36, cd2
# Negative:  cd56.2, cd16, cd335, cd337, cd244, cd56.1, cd122, cd45ra, cd43, cd158b
# 	   cd314, cd158e1, cd38.2, cd38.1, cd158, cd305, cd57, cd22, cd72, cd8a
# 	   cd19, cd271, cd307c.fcrl3, tigit, igm, cd81, igd, cx3cr1, cd138.1, cd161
# PC_ 4
# Positive:  cd110, cd42b, clec1b, cd49b, cd226, cd62p, cd102, gp130, cd9, cd69
# 	   cd41, cd194, cd112, cd61, cd47, cd34, cd107a, cd274, cd164, cd29
# 	   cd63, cd31, cd133.2, cd154, cd141, cd138.1, cd27, cd36, tslpr, cd45rb
# Negative:  cd18, cd45.2, cd44.1, cd44.2, cd48, cd11b.1, cd93, cd11b.2, cd14, cd49d
# 	   cd205, cd305, cd155, cd172a, cd11c, cd43, cd64, cd86, cd35, clec12a
# 	   cd95, cd119, cd354, cd39, folate, cd45.1, cd13, cd54, cd1d, cd57
# PC_ 5
# Positive:  cd338, cd138.1, cd243, cd325, cd275.1, cd138.2, cd59, cd83, vegfr3, cd202b
# 	   cd68, cd319, cd66b, cd199, cd357, cd133.1, cd70, cd140b, siglec.8, gp130
# 	   cd252, cd142, cd294, cd324, cd158f, cd307d, cd144, cd126, podoplanin, c5l2
# Negative:  cd45.2, cd49d, cd47, cd226, cd314, cd69, cd44.1, cd102, cd44.2, cd8
# 	   cd29, cd46, cd8a, cd73, cd81, cd62p, cd195, cd43, cd48, clec1b
# 	   cd71, cd18, cd161, cd16, cd42b, integrin.7, cd99, cd244, cd49b, cd2
#
# Warning message:
# "Cannot add objects with duplicate keys (offending key: PC_), setting key to 'pca_rpca_adt_'"
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from normpca_rpca_adt_ to normpcarpcaadt_"
# Warning message:
# "All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to normpcarpcaadt_"
# Calculating kernel bandwidths
#
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#
# 03:44:17 UMAP embedding parameters a = 0.9922 b = 1.112
#
# 03:44:19 Commencing smooth kNN distance calibration using 64 threads
#
# 03:44:22 Initializing from normalized Laplacian + noise
#
# 03:44:24 Commencing optimization for 200 epochs, with 733600 positive edges
#
# 03:44:39 Optimization finished
#
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding counts for rna
#
# Adding data for rna
#
# No variable features found for rna
#
# No feature-level metadata found for rna
#
# Adding counts for adt
#
# Adding data for adt
#
# No variable features found for adt
#
# No feature-level metadata found for adt
#
# Adding data for rna_int
#
# Adding scale.data for rna_int
#
# Adding variable features for rna_int
#
# No feature-level metadata found for rna_int
#
# Adding data for adt_int
#
# Adding scale.data for adt_int
#
# Adding variable features for adt_int
#
# No feature-level metadata found for adt_int
#
# Adding cell embeddings for pca_rpca_rna
#
# Adding loadings for pca_rpca_rna
#
# No projected loadings for pca_rpca_rna
#
# Adding standard deviations for pca_rpca_rna
#
# No JackStraw data for pca_rpca_rna
#
# Adding cell embeddings for pca_rpca_adt
#
# Adding loadings for pca_rpca_adt
#
# No projected loadings for pca_rpca_adt
#
# Adding standard deviations for pca_rpca_adt
#
# No JackStraw data for pca_rpca_adt
#
# Adding cell embeddings for umap
#
# No loadings for umap
#
# No projected loadings for umap
#
# No standard deviations for umap
#
# No JackStraw data for umap
#
# Validating h5Seurat file
#
# Initializing adt with data
#
# Adding counts for adt
#
# Adding miscellaneous information for adt
#
# Initializing adt_int with data
#
# Adding scale.data for adt_int
#
# Adding variable feature information for adt_int
#
# Initializing rna with data
#
# Adding counts for rna
#
# Adding miscellaneous information for rna
#
# Initializing rna_int with data
#
# Adding scale.data for rna_int
#
# Adding variable feature information for rna_int
#
# Adding reduction pca_rpca_adt
#
# Adding cell embeddings for pca_rpca_adt
#
# Adding feature loadings for pca_rpca_adt
#
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from pca_rpca_adt_ to pcarpcaadt_"
# Warning message:
# "All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to pcarpcaadt_"
# Adding miscellaneous information for pca_rpca_adt
#
# Adding reduction umap
#
# Adding cell embeddings for umap
#
# Adding miscellaneous information for umap
#
# Adding reduction pca_rpca_rna
#
# Adding cell embeddings for pca_rpca_rna
#
# Adding feature loadings for pca_rpca_rna
#
# Adding miscellaneous information for pca_rpca_rna
#
# Adding graph wknn
#
# Adding graph wsnn
#
# Adding neighbors weighted.nn
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results
#
# Scaling features for provided objects
#
# Computing within dataset neighborhoods
#
# Finding all pairwise anchors
#
# Projecting new data onto SVD
#
# Projecting new data onto SVD
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 1821 anchors
#
# Merging dataset 2 into 1
#
# Extracting anchors for merged samples
#
# Finding integration vectors
#
# Finding integration vector weights
#
# Integrating data
#
# PC_ 1
# Positive:  RPS27, RPS12, RPL13, CD3E, CD3D, TRBC2, IL7R, LTB, IL32, CD3G
# 	   CD2, ARL4C, MALAT1, TRAC, LCK, SYNE2, CD247, LINC00861, CLEC2D, TRBC1
# 	   ISG20, TCF7, CD7, SKAP1, SPOCK2, LBH, GZMM, CD52, STK17A, BCL11B
# Negative:  FCN1, SERPINA1, MNDA, CST3, CSTA, CLEC12A, FGL2, LYZ, CYBB, CFD
# 	   S100A9, NCF2, MPEG1, VCAN, CD68, SPI1, TYMP, S100A8, CD14, CLEC7A
# 	   CFP, MS4A6A, GRN, TNFAIP2, LST1, AIF1, FTL, IGSF6, RETN, KCTD12
# PC_ 2
# Positive:  NKG7, GZMA, PRF1, KLRD1, CST7, HOPX, KLRF1, S100A4, FGFBP2, GNLY
# 	   GZMH, CTSW, ABHD17A, GZMM, GZMB, ADGRG1, CCL5, SRGN, SPON2, TRDC
# 	   MYBL1, CD63, ID2, CCL4, CX3CR1, SAMD3, CD247, IL32, TTC38, S100A11
# Negative:  MS4A1, CD79A, BANK1, TCL1A, TNFRSF13C, IGHM, LINC00926, BCL7A, IGHD, VPREB3
# 	   CD79B, BLNK, SPIB, POU2AF1, FCRL1, P2RX5, BCL11A, HLA-DOB, IRF8, RALGPS2
# 	   HLA-DOA, AFF3, PPP1R14A, JCHAIN, TSPAN13, ARHGAP24, PLPP5, SWAP70, COBLL1, GNG7
# PC_ 3
# Positive:  IL7R, MAL, LEF1, TCF7, CCR7, RCAN3, CD27, NOSIP, CD3G, CD3D
# 	   RPS12, TRAC, RPL13, LRRN3, RGCC, OXNAD1, CAMK4, RGS10, LTB, BCL11B
# 	   PIK3IP1, CD3E, TRAT1, VIM, LDLRAP1, FAM102A, TSHZ2, TRABD2A, LINC01550, IL6ST
# Negative:  GZMB, GNLY, KLRD1, FGFBP2, PRF1, NKG7, SPON2, CST7, KLRF1, GZMA
# 	   ADGRG1, GZMH, FCGR3A, CTSW, HOPX, CLIC3, PTGDR, CX3CR1, CCL4, TRDC
# 	   PLEK, TTC38, CCL5, TBX21, IL2RB, MATK, S1PR5, FASLG, CXXC5, NCR3
# PC_ 4
# Positive:  S100A12, TUBB1, S100A8, PF4, PPBP, CAVIN2, GNG11, ITGA2B, S100A9, ACRBP
# 	   VCAN, NRGN, CD14, VNN2, C2orf88, NCF1, HIST1H2AC, RBP7, CMTM2, CLEC1B
# 	   CYP1B1, PRKAR2B, LYZ, CCL5, MNDA, RGS18, CSF3R, STEAP4, CCL3L1, CD9
# Negative:  MALAT1, PLD4, CDKN1C, BATF3, RHOC, ENHO, FCER1A, ADA, FABP5, CKB
# 	   IL3RA, HLA-DQA1, CLEC10A, PPP1R14B, SIGLEC10, ZNF703, IFITM3, MARCKSL1, ABI3, PID1
# 	   HMOX1, MYOF, RAB34, HES4, CAMK1, NEURL1, CTSL, TCF7L2, CSF1R, RUFY3
# PC_ 5
# Positive:  MALAT1, S100A12, QPCT, CD14, MGST1, NAIP, RNASE6, ITGAM, CYP1B1, CD163
# 	   CREB5, CLEC4E, STEAP4, VNN2, VCAN, MCEMP1, SIRPA, FOLR3, CSF3R, PTAFR
# 	   RNASE2, CLEC4D, CRISPLD2, CEBPD, FAM198B, MS4A6A, CCR2, ASGR1, TFEC, BST1
# Negative:  PPBP, TUBB1, PF4, CAVIN2, GNG11, PRKAR2B, ACRBP, ITGA2B, CDKN1C, C2orf88
# 	   CLEC1B, MAP3K7CL, TSC22D1, MGLL, ABCC3, CKB, MMD, HIST1H2AC, FAM110A, NRGN
# 	   GP1BA, TMSB4X, BATF3, SIGLEC10, TPM1, PTGS1, TCF7L2, MTURN, MARCH2, TMEM140
#
# Scaling features for provided objects
#
# Computing within dataset neighborhoods
#
# Finding all pairwise anchors
#
# Projecting new data onto SVD
#
# Projecting new data onto SVD
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 2328 anchors
#
# Merging dataset 2 into 1
#
# Extracting anchors for merged samples
#
# Finding integration vectors
#
# Finding integration vector weights
#
# Integrating data
#
# Warning message:
# "Cannot add objects with duplicate keys (offending key: integrated_), setting key to 'adt_int_'"
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from adt_int_ to adtint_"
# PC_ 1
# Positive:  cd2, cd3.2, cd3.1, cd127, cd27, cd28, tcrab, cd45rb, cd52, cd278
# 	   cd96, cd81, cd26.2, cd109, cd307e, cd4.1, cd45ra, cd8, cd99, cd8a
# 	   cd314, cd4.2, cd73, integrin.7, cd279, cd25, cd122, cd56.1, galectin.9, cd161
# Negative:  clec12a, cd63, cd31, cd36, cd41, cd64, cd61, cd86, cd11b.2, cd155
# 	   cd93, cd9, cd11c, cd172a, cd119, cd62p, cd35, cd14, cd11b.1, cd49b
# 	   clec1b, cd42b, cd29, cd13, cd110, cd39, cd69, cd141, cd55, cd354
# PC_ 2
# Positive:  cd22, cd19, cd72, cd268, cd21, cd20, igd, cd196, igm, cd275.2
# 	   hla.dr, cd1c, cd39, cd79b, cd73, cd272, cd40, cd200, cd305, cd24
# 	   cd164, cd35, cd185, cd55, cd98, cd71, cd45ra, cd171, cd52, integrin.7
# Negative:  cd43, cd18, cd2, cd99, cd244, cd8a, cd122, cd314, cd226, cd45ro
# 	   cd8, cd96, galectin.9, cd3.2, cd3.1, cd95, cd279, cd161, tcrab, cd140b
# 	   cd127, cd69, cd62p, cd49a, cd16, cd110, cd57, cd56.2, cd29, cd195
# PC_ 3
# Positive:  cd4.2, cd4.1, cd109, cd44.2, cd44.1, cd28, cd127, cd48, cd45ro, cd307e
# 	   cd3.2, cd55, cd3.1, cd52, cd27, cd126, cd49a, cd278, cd46, cd25
# 	   cd26.2, tcrab, cd95, gp130, cd205, cd47, cd209, cd96, cd45rb, cd106
# Negative:  cd56.2, cd16, cd335, cd244, cd337, cd43, cd122, cd314, cd56.1, cd158b
# 	   cd158e1, cd45ra, cd38.2, cd38.1, cd8a, cd158, cd57, cd8, cd271, tigit
# 	   cd161, cd81, cx3cr1, cd307c.fcrl3, cd138.1, cd305, cd319, cd357, cd325, cd275.1
# PC_ 4
# Positive:  cd42b, cd110, cd226, clec1b, cd49b, cd102, cd62p, cd69, cd47, gp130
# 	   cd9, cd41, cd112, cd194, cd61, cd34, cd29, cd107a, cd164, cd274
# 	   cd31, cd63, cd154, cd36, cd133.2, cd71, cd141, cd27, tslpr, cd273
# Negative:  cd18, cd45.2, cd44.1, cd44.2, cd48, cd11b.1, cd93, cd11b.2, cd14, cd64
# 	   cd305, cd155, cd205, cd11c, cd35, clec12a, cd49d, cd354, cd43, cd86
# 	   cd172a, cd95, cd119, cd38.1, cd1d, cd39, folate, cd13, cd38.2, cd54
# PC_ 5
# Positive:  cd338, cd243, cd138.1, cd275.1, cd325, cd138.2, vegfr3, cd202b, cd59, cd83
# 	   cd68, cd319, gp130, cd199, cd66b, ccr10, cd357, cd70, cd142, cd133.1
# 	   cd140b, cd307d, cd140a, cd252, cd370, cd294, cd158f, siglec.8, cd126, podoplanin
# Negative:  cd45.2, cd49d, cd44.2, cd314, cd47, cd44.1, cd226, cd8, cd18, cd48
# 	   cd43, cd29, cd8a, cd69, cd46, cd195, cd81, cd16, cd102, cd161
# 	   cd73, cd71, integrin.7, cd2, cd244, cd99, cd54, cd62p, cd196, cd57
#
# Warning message:
# "Cannot add objects with duplicate keys (offending key: PC_), setting key to 'pca_rpca_adt_'"
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from normpca_rpca_adt_ to normpcarpcaadt_"
# Warning message:
# "All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to normpcarpcaadt_"
# Calculating kernel bandwidths
#
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#
# 04:08:28 UMAP embedding parameters a = 0.9922 b = 1.112
#
# 04:08:30 Commencing smooth kNN distance calibration using 64 threads
#
# 04:08:33 Initializing from normalized Laplacian + noise
#
# 04:08:36 Commencing optimization for 200 epochs, with 903136 positive edges
#
# 04:08:53 Optimization finished
#
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding counts for rna
#
# Adding data for rna
#
# No variable features found for rna
#
# No feature-level metadata found for rna
#
# Adding counts for adt
#
# Adding data for adt
#
# No variable features found for adt
#
# No feature-level metadata found for adt
#
# Adding data for rna_int
#
# Adding scale.data for rna_int
#
# Adding variable features for rna_int
#
# No feature-level metadata found for rna_int
#
# Adding data for adt_int
#
# Adding scale.data for adt_int
#
# Adding variable features for adt_int
#
# No feature-level metadata found for adt_int
#
# Adding cell embeddings for pca_rpca_rna
#
# Adding loadings for pca_rpca_rna
#
# No projected loadings for pca_rpca_rna
#
# Adding standard deviations for pca_rpca_rna
#
# No JackStraw data for pca_rpca_rna
#
# Adding cell embeddings for pca_rpca_adt
#
# Adding loadings for pca_rpca_adt
#
# No projected loadings for pca_rpca_adt
#
# Adding standard deviations for pca_rpca_adt
#
# No JackStraw data for pca_rpca_adt
#
# Adding cell embeddings for umap
#
# No loadings for umap
#
# No projected loadings for umap
#
# No standard deviations for umap
#
# No JackStraw data for umap
#
# Validating h5Seurat file
#
# Initializing adt with data
#
# Adding counts for adt
#
# Adding miscellaneous information for adt
#
# Initializing adt_int with data
#
# Adding scale.data for adt_int
#
# Adding variable feature information for adt_int
#
# Initializing rna with data
#
# Adding counts for rna
#
# Adding miscellaneous information for rna
#
# Initializing rna_int with data
#
# Adding scale.data for rna_int
#
# Adding variable feature information for rna_int
#
# Adding reduction pca_rpca_adt
#
# Adding cell embeddings for pca_rpca_adt
#
# Adding feature loadings for pca_rpca_adt
#
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from pca_rpca_adt_ to pcarpcaadt_"
# Warning message:
# "All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to pcarpcaadt_"
# Adding miscellaneous information for pca_rpca_adt
#
# Adding reduction umap
#
# Adding cell embeddings for umap
#
# Adding miscellaneous information for umap
#
# Adding reduction pca_rpca_rna
#
# Adding cell embeddings for pca_rpca_rna
#
# Adding feature loadings for pca_rpca_rna
#
# Adding miscellaneous information for pca_rpca_rna
#
# Adding graph wknn
#
# Adding graph wsnn
#
# Adding neighbors weighted.nn
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results
#
# Scaling features for provided objects
#
# Computing within dataset neighborhoods
#
# Finding all pairwise anchors
#
# Projecting new data onto SVD
#
# Projecting new data onto SVD
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 3117 anchors
#
# Merging dataset 2 into 1
#
# Extracting anchors for merged samples
#
# Finding integration vectors
#
# Finding integration vector weights
#
# Integrating data
#
# PC_ 1
# Positive:  RPS27, RPS12, RPL13, CD3E, TRBC2, CD3D, IL7R, IL32, MALAT1, LTB
# 	   CD2, CD3G, ARL4C, TRAC, SYNE2, CD247, LCK, LINC00861, CLEC2D, TRBC1
# 	   ISG20, TCF7, SKAP1, CD7, GZMM, LBH, SPOCK2, CD52, STK17A, RORA
# Negative:  FCN1, SERPINA1, CST3, MNDA, CSTA, LYZ, CLEC12A, FGL2, S100A9, CYBB
# 	   CFD, NCF2, MPEG1, TYMP, VCAN, S100A8, CFP, SPI1, CD14, CD68
# 	   FTL, RETN, AIF1, GRN, CLEC7A, LST1, MS4A6A, TNFAIP2, IGSF6, CTSS
# PC_ 2
# Positive:  MS4A1, CD79A, BANK1, TNFRSF13C, TCL1A, IGHM, LINC00926, BCL7A, SPIB, BLNK
# 	   CD79B, POU2AF1, FCRL1, IGHD, P2RX5, BCL11A, JCHAIN, IRF8, PPP1R14A, VPREB3
# 	   RALGPS2, HLA-DOA, HLA-DOB, FCRLA, AFF3, FAM30A, TSPAN13, COBLL1, ARHGAP24, SWAP70
# Negative:  GZMA, NKG7, PRF1, KLRD1, S100A4, CST7, ABHD17A, GZMM, HOPX, KLRF1
# 	   CTSW, FGFBP2, GNLY, GZMH, IL32, CCL5, MYBL1, ADGRG1, ID2, SRGN
# 	   CD63, TRDC, CD247, GZMB, S100A11, SPON2, CX3CR1, SPN, S100A6, SAMD3
# PC_ 3
# Positive:  MAL, IL7R, LEF1, CCR7, RCAN3, TCF7, CD27, NOSIP, LRRN3, RPS12
# 	   RPL13, CD3G, CD3D, RGCC, OXNAD1, LTB, TRAC, CAMK4, PIK3IP1, BCL11B
# 	   RGS10, TRAT1, CD3E, TRABD2A, TSHZ2, FAM102A, LDLRAP1, VIM, LINC01550, IL6ST
# Negative:  GZMB, KLRD1, GNLY, FGFBP2, PRF1, NKG7, CST7, SPON2, KLRF1, GZMA
# 	   FCGR3A, CTSW, ADGRG1, GZMH, HOPX, CX3CR1, CLIC3, PTGDR, TRDC, TTC38
# 	   PLEK, CCL5, CCL4, TBX21, FASLG, IL2RB, MATK, AKR1C3, S1PR5, CEP78
# PC_ 4
# Positive:  S100A12, S100A8, S100A9, VNN2, VCAN, CD14, RBP7, NCF1, CYP1B1, STEAP4
# 	   RGS2, LRRK2, CLEC4D, CLEC4E, CSF3R, MS4A1, CMTM2, LYZ, ITGAM, AQP9
# 	   LINC00926, CTSS, QPCT, FPR1, MNDA, ZFP36L1, NEAT1, CDA, CCL5, BANK1
# Negative:  PLD4, FCER1A, IL3RA, ENHO, CDKN1C, CLEC10A, FABP5, RHOC, HLA-DQA1, MALAT1
# 	   ADA, BATF3, SERPINF1, PPP1R14B, GSN, CLEC4C, LILRB4, CKB, ZNF703, FLT3
# 	   RAB34, ITM2C, PID1, RUFY3, SNRNP25, MYOF, ABI3, CD1C, SPINT2, IDH3A
# PC_ 5
# Positive:  CDKN1C, CKB, TCF7L2, FCGR3B, FCGR3A, SIGLEC10, SMIM25, HES4, IFITM3, BATF3
# 	   FAM110A, ZNF703, TNFRSF8, NEURL1, HMOX1, TMSB4X, CTSL, PPBP, CAMK1, RRAS
# 	   PF4, RHOC, LINC02432, ACRBP, TUBB1, MYOF, MGLL, MS4A7, GNG11, FTH1
# Negative:  RNASE6, CCR2, MGST1, S100A12, CD163, QPCT, NAIP, RNASE2, MS4A6A, CAPG
# 	   VCAN, CREB5, C9orf139, CYP1B1, PTAFR, SIRPA, CD14, CRTAP, MCEMP1, TFEC
# 	   CSF3R, ITGAM, BAZ2B, CLEC4E, CEBPD, LMNB1, CD36, FES, CRISPLD2, PLA2G7
#
# Scaling features for provided objects
#
# Computing within dataset neighborhoods
#
# Finding all pairwise anchors
#
# Projecting new data onto SVD
#
# Projecting new data onto SVD
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 3913 anchors
#
# Merging dataset 2 into 1
#
# Extracting anchors for merged samples
#
# Finding integration vectors
#
# Finding integration vector weights
#
# Integrating data
#
# Warning message:
# "Cannot add objects with duplicate keys (offending key: integrated_), setting key to 'adt_int_'"
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from adt_int_ to adtint_"
# PC_ 1
# Positive:  cd2, cd3.2, cd3.1, cd127, cd27, tcrab, cd28, cd45rb, cd278, cd52
# 	   cd81, cd96, cd26.2, cd45ra, cd109, cd8, cd314, cd8a, cd307e, cd4.1
# 	   cd73, integrin.7, cd99, cd279, cd4.2, cd25, cd122, cd56.1, cd161, galectin.9
# Negative:  clec12a, cd63, cd31, cd41, cd36, cd64, cd61, cd86, cd93, cd11b.2
# 	   cd9, cd155, cd11c, cd62p, cd119, cd172a, cd49b, cd14, clec1b, cd11b.1
# 	   cd35, cd42b, cd110, cd29, cd13, cd69, cd39, cd55, cd141, cd102
# PC_ 2
# Positive:  cd22, cd19, cd268, cd72, cd20, cd21, igd, cd196, igm, cd275.2
# 	   hla.dr, cd1c, cd39, cd79b, cd73, cd40, cd272, cd24, cd164, cd185
# 	   cd200, cd305, cd35, cd55, cd71, cd98, cd45ra, cd52, cd171, integrin.7
# Negative:  cd43, cd18, cd2, cd244, cd99, cd8a, cd314, cd122, cd8, cd226
# 	   cd45ro, cd96, galectin.9, cd3.2, cd57, cd3.1, cd56.2, cd56.1, cd16, cd279
# 	   tcrab, cd140b, cd161, lox.1, cd324, cd271, cd127, cd195, cd95, cd62p
# PC_ 3
# Positive:  cd4.2, cd4.1, cd109, cd28, cd44.2, cd127, cd44.1, cd48, cd307e, cd45ro
# 	   cd3.2, cd3.1, cd27, cd55, cd52, cd278, cd49a, cd126, cd46, cd25
# 	   cd26.2, gp130, tcrab, cd209, cd47, cd45rb, cd95, cd96, cd106, cd205
# Negative:  cd56.2, cd16, cd335, cd244, cd337, cd43, cd314, cd122, cd56.1, cd45ra
# 	   cd158b, cd158e1, cd38.1, cd38.2, cd57, cd158, cd8a, cd8, cd271, tigit
# 	   cx3cr1, cd161, cd305, cd81, cd138.1, cd307c.fcrl3, cd325, cd275.1, cd357, cd319
# PC_ 4
# Positive:  cd226, cd42b, cd110, clec1b, cd49b, cd47, cd69, cd102, cd62p, cd9
# 	   cd41, cd112, cd61, gp130, cd194, cd34, cd29, cd164, cd107a, cd274
# 	   cd63, cd31, cd71, cd123, cd36, cd154, cd45rb, cd141, tslpr, cd133.2
# Negative:  cd18, cd11b.1, cd45.2, cd44.1, cd48, cd93, cd11b.2, cd14, cd44.2, cd64
# 	   cd11c, cd354, cd35, cd155, clec12a, cd205, cd1d, cd86, cd172a, cd305
# 	   cd95, cd119, cd39, cd38.1, cd13, folate, cd49a, cd43, cd38.2, cd45ro
# PC_ 5
# Positive:  cd45.2, cd49d, cd44.2, cd44.1, cd18, cd314, cd48, cd43, cd8, cd195
# 	   cd47, cd8a, cd81, cd99, cd29, cd46, cd161, cd16, cd54, cd2
# 	   cd73, integrin.7, cd71, cd226, cd45.1, cd52, cd244, cd196, cd279, cd305
# Negative:  cd338, cd243, cd138.1, cd275.1, cd325, vegfr3, cd138.2, gp130, cd202b, cd68
# 	   cd83, cd59, cd319, ccr10, cd199, cd66b, cd142, cd370, cd357, cd70
# 	   cd133.1, cd140b, cd140a, cd307d, cd158f, cd252, cd294, cd38.1, cd194, cd126
#
# Warning message:
# "Cannot add objects with duplicate keys (offending key: PC_), setting key to 'pca_rpca_adt_'"
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from normpca_rpca_adt_ to normpcarpcaadt_"
# Warning message:
# "All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to normpcarpcaadt_"
# Calculating kernel bandwidths
#
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#
# 04:40:18 UMAP embedding parameters a = 0.9922 b = 1.112
#
# 04:40:20 Commencing smooth kNN distance calibration using 64 threads
#
# 04:40:22 Initializing from normalized Laplacian + noise
#
# 04:40:27 Commencing optimization for 200 epochs, with 1185182 positive edges
#
# 04:40:49 Optimization finished
#
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding counts for rna
#
# Adding data for rna
#
# No variable features found for rna
#
# No feature-level metadata found for rna
#
# Adding counts for adt
#
# Adding data for adt
#
# No variable features found for adt
#
# No feature-level metadata found for adt
#
# Adding data for rna_int
#
# Adding scale.data for rna_int
#
# Adding variable features for rna_int
#
# No feature-level metadata found for rna_int
#
# Adding data for adt_int
#
# Adding scale.data for adt_int
#
# Adding variable features for adt_int
#
# No feature-level metadata found for adt_int
#
# Adding cell embeddings for pca_rpca_rna
#
# Adding loadings for pca_rpca_rna
#
# No projected loadings for pca_rpca_rna
#
# Adding standard deviations for pca_rpca_rna
#
# No JackStraw data for pca_rpca_rna
#
# Adding cell embeddings for pca_rpca_adt
#
# Adding loadings for pca_rpca_adt
#
# No projected loadings for pca_rpca_adt
#
# Adding standard deviations for pca_rpca_adt
#
# No JackStraw data for pca_rpca_adt
#
# Adding cell embeddings for umap
#
# No loadings for umap
#
# No projected loadings for umap
#
# No standard deviations for umap
#
# No JackStraw data for umap
#
# Validating h5Seurat file
#
# Initializing adt with data
#
# Adding counts for adt
#
# Adding miscellaneous information for adt
#
# Initializing adt_int with data
#
# Adding scale.data for adt_int
#
# Adding variable feature information for adt_int
#
# Initializing rna with data
#
# Adding counts for rna
#
# Adding miscellaneous information for rna
#
# Initializing rna_int with data
#
# Adding scale.data for rna_int
#
# Adding variable feature information for rna_int
#
# Adding reduction pca_rpca_adt
#
# Adding cell embeddings for pca_rpca_adt
#
# Adding feature loadings for pca_rpca_adt
#
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from pca_rpca_adt_ to pcarpcaadt_"
# Warning message:
# "All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to pcarpcaadt_"
# Adding miscellaneous information for pca_rpca_adt
#
# Adding reduction umap
#
# Adding cell embeddings for umap
#
# Adding miscellaneous information for umap
#
# Adding reduction pca_rpca_rna
#
# Adding cell embeddings for pca_rpca_rna
#
# Adding feature loadings for pca_rpca_rna
#
# Adding miscellaneous information for pca_rpca_rna
#
# Adding graph wknn
#
# Adding graph wsnn
#
# Adding neighbors weighted.nn
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results
#
# Scaling features for provided objects
#
# Computing within dataset neighborhoods
#
# Finding all pairwise anchors
#
# Projecting new data onto SVD
#
# Projecting new data onto SVD
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 3999 anchors
#
# Merging dataset 2 into 1
#
# Extracting anchors for merged samples
#
# Finding integration vectors
#
# Finding integration vector weights
#
# Integrating data
#
# PC_ 1
# Positive:  RPS27, RPS12, RPL13, CD3E, TRBC2, CD3D, IL7R, IL32, MALAT1, CD2
# 	   ARL4C, LTB, CD3G, TRAC, SYNE2, LCK, CD247, CLEC2D, LINC00861, TRBC1
# 	   ISG20, TCF7, SKAP1, CD7, GZMM, LBH, SPOCK2, CD52, STK17A, RORA
# Negative:  FCN1, SERPINA1, MNDA, CST3, LYZ, CSTA, CLEC12A, S100A9, FGL2, CYBB
# 	   CFD, NCF2, MPEG1, TYMP, S100A8, RETN, VCAN, CFP, CD14, FTL
# 	   CD68, SPI1, GRN, LST1, MS4A6A, CLEC7A, AIF1, TNFAIP2, IGSF6, CTSS
# PC_ 2
# Positive:  NKG7, GZMA, PRF1, KLRD1, CST7, S100A4, GNLY, FGFBP2, KLRF1, CTSW
# 	   GZMH, HOPX, ABHD17A, GZMM, ADGRG1, CCL5, SRGN, GZMB, CD63, MYBL1
# 	   ID2, SPON2, TRDC, CX3CR1, IL32, S100A11, CD247, CCL4, SAMD3, SPN
# Negative:  MS4A1, CD79A, BANK1, TNFRSF13C, TCL1A, IGHM, LINC00926, SPIB, BCL7A, BLNK
# 	   POU2AF1, CD79B, FCRL1, P2RX5, IGHD, PPP1R14A, JCHAIN, BCL11A, FCRLA, VPREB3
# 	   HLA-DOB, RALGPS2, HLA-DOA, IRF8, FAM30A, COBLL1, AFF3, TSPAN13, CD24, SWAP70
# PC_ 3
# Positive:  MAL, IL7R, LEF1, CCR7, RCAN3, TCF7, CD27, NOSIP, LRRN3, CD3G
# 	   RPS12, CD3D, RPL13, OXNAD1, RGCC, TRAC, LTB, CAMK4, PIK3IP1, RGS10
# 	   BCL11B, TRAT1, TRABD2A, CD3E, TSHZ2, FAM102A, LINC01550, LDLRAP1, FHIT, VIM
# Negative:  GZMB, GNLY, KLRD1, FGFBP2, PRF1, NKG7, CST7, SPON2, KLRF1, GZMA
# 	   FCGR3A, GZMH, CTSW, ADGRG1, HOPX, CX3CR1, PTGDR, CLIC3, TTC38, TRDC
# 	   PLEK, CCL5, TBX21, CCL4, FASLG, CEP78, IL2RB, MATK, NCR3, C1orf21
# PC_ 4
# Positive:  S100A12, S100A8, S100A9, VCAN, VNN2, CD14, NCF1, RBP7, CYP1B1, CLEC4D
# 	   STEAP4, CSF3R, RGS2, CLEC4E, LRRK2, ITGAM, AQP9, QPCT, FPR1, MS4A1
# 	   LINC00926, LYZ, IER3, CMTM2, MNDA, MCEMP1, MEGF9, CCL5, ZFP36L1, CDA
# Negative:  PLD4, CDKN1C, ENHO, RHOC, FCER1A, IL3RA, CLEC10A, CKB, BATF3, HLA-DQA1
# 	   MALAT1, ZNF703, ADA, FABP5, MYOF, IFITM3, ABI3, FCGR3B, NEURL1, PID1
# 	   PPP1R14B, GSN, FAM110A, LILRB4, HMOX1, CSF1R, SIGLEC10, MARCKSL1, MS4A4A, CTSL
# PC_ 5
# Positive:  CDKN1C, CKB, TCF7L2, FCGR3B, FCGR3A, SIGLEC10, PPBP, SMIM25, HES4, PF4
# 	   TUBB1, ACRBP, GNG11, IFITM3, CAVIN2, ITGA2B, BATF3, FAM110A, TMSB4X, ZNF703
# 	   NEURL1, PRKAR2B, TNFRSF8, MGLL, HMOX1, FTH1, CTSL, ABCC3, RRAS, CAMK1
# Negative:  RNASE6, MGST1, CCR2, CD163, RNASE2, QPCT, NAIP, S100A12, CAPG, C9orf139
# 	   CREB5, PTAFR, SIRPA, CYP1B1, MS4A6A, CRTAP, MCEMP1, LMNB1, FES, TFEC
# 	   VCAN, ITGAM, PLA2G7, FAM198B, CLEC4E, BAZ2B, ATP6V0A1, CEBPD, CD14, CRISPLD2
#
# Scaling features for provided objects
#
# Computing within dataset neighborhoods
#
# Finding all pairwise anchors
#
# Projecting new data onto SVD
#
# Projecting new data onto SVD
#
# Finding neighborhoods
#
# Finding anchors
#
# 	Found 3701 anchors
#
# Merging dataset 2 into 1
#
# Extracting anchors for merged samples
#
# Finding integration vectors
#
# Finding integration vector weights
#
# Integrating data
#
# Warning message:
# "Cannot add objects with duplicate keys (offending key: integrated_), setting key to 'adt_int_'"
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from adt_int_ to adtint_"
# PC_ 1
# Positive:  cd2, cd3.2, cd3.1, cd127, cd27, tcrab, cd45rb, cd28, cd278, cd52
# 	   cd81, cd96, cd45ra, cd26.2, cd109, cd8, cd314, cd8a, cd307e, cd4.1
# 	   integrin.7, cd73, cd99, cd279, cd4.2, cd122, cd56.1, cd25, cd161, cd200
# Negative:  clec12a, cd63, cd31, cd64, cd36, cd41, cd61, cd93, cd11b.2, cd86
# 	   cd155, cd9, cd11c, cd62p, cd119, cd172a, cd35, cd14, cd11b.1, cd49b
# 	   clec1b, cd42b, cd29, cd110, cd13, cd69, cd39, cd55, cd141, cd102
# PC_ 2
# Positive:  cd22, cd19, cd268, cd20, cd72, cd21, igd, cd196, igm, cd275.2
# 	   cd1c, hla.dr, cd39, cd73, cd79b, cd40, cd272, cd185, cd164, cd24
# 	   cd35, cd200, cd55, cd305, cd71, cd98, cd52, cd25, cd171, cd205
# Negative:  cd43, cd18, cd244, cd2, cd314, cd8a, cd122, cd8, cd99, cd226
# 	   cd56.2, cd57, cd16, cd56.1, cd96, galectin.9, cd45ro, cd161, cd140b, cd271
# 	   cd279, tcrab, cd335, cd3.2, lox.1, cd324, cd3.1, cd199, cd195, cd158b
# PC_ 3
# Positive:  cd4.2, cd4.1, cd109, cd28, cd127, cd307e, cd44.2, cd48, cd3.2, cd45ro
# 	   cd44.1, cd3.1, cd27, cd278, cd52, cd49a, cd126, cd55, cd46, cd25
# 	   gp130, cd26.2, tcrab, cd45rb, cd209, cd96, cd47, cd95, cd106, galectin.9
# Negative:  cd56.2, cd16, cd244, cd335, cd337, cd43, cd314, cd56.1, cd122, cd158b
# 	   cd45ra, cd158e1, cd57, cd38.2, cd38.1, cd158, cd8a, cd271, tigit, cd8
# 	   cx3cr1, cd305, cd161, cd81, cd72, cd22, cd19, igm, cd307c.fcrl3, igd
# PC_ 4
# Positive:  cd18, cd45.2, cd11b.1, cd44.1, cd48, cd93, cd11b.2, cd14, cd44.2, cd64
# 	   cd11c, cd354, cd35, cd155, clec12a, cd305, cd1d, cd205, cd86, cd95
# 	   cd172a, cd119, cd13, cd39, cd49a, cd38.1, cd45ro, folate, cd43, cd45.1
# Negative:  cd226, cd42b, cd110, clec1b, cd49b, cd69, cd47, cd102, cd62p, cd41
# 	   cd9, cd112, cd61, gp130, cd194, cd34, cd29, cd107a, cd164, cd274
# 	   cd31, cd63, cd71, cd123, cd36, cd154, cd141, cd45rb, cd27, cd45ra
# PC_ 5
# Positive:  cd45.2, cd49d, cd44.2, cd44.1, cd18, cd314, cd8, cd48, cd195, cd8a
# 	   cd47, cd43, cd99, cd29, cd81, cd2, cd226, cd73, cd46, cd54
# 	   cd161, cd279, cd52, cd45ro, cd45.1, cd71, cd102, cd196, integrin.7, cd69
# Negative:  cd338, cd243, cd138.1, cd275.1, gp130, cd138.2, vegfr3, cd68, cd202b, cd325
# 	   cd59, cd83, ccr10, cd38.1, cd319, cd199, cd142, cd66b, cd370, cd140a
# 	   cd38.2, cd357, cd140b, cd133.1, cd70, cd126, cd307d, cd200, cd158f, cd294
#
# Warning message:
# "Cannot add objects with duplicate keys (offending key: PC_), setting key to 'pca_rpca_adt_'"
# Calculating cell-specific modality weights
#
# Finding 20 nearest neighbors for each modality.
#
# Warning message:
# "Keys should be one or more alphanumeric characters followed by an underscore, setting key from normpca_rpca_adt_ to normpcarpcaadt_"
# Warning message:
# "All keys should be one or more alphanumeric characters followed by an underscore '_', setting key to normpcarpcaadt_"
# Calculating kernel bandwidths
#
# Finding multimodal neighbors
#
# Constructing multimodal KNN graph
#
# Constructing multimodal SNN graph
#
# 05:22:14 UMAP embedding parameters a = 0.9922 b = 1.112
#
# 05:22:17 Commencing smooth kNN distance calibration using 64 threads
#
# 05:22:19 Initializing from normalized Laplacian + noise
#
# 05:22:31 Commencing optimization for 200 epochs, with 1466228 positive edges
#
# 05:23:00 Optimization finished
#
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding counts for rna
#
# Adding data for rna
#
# No variable features found for rna
#
# No feature-level metadata found for rna
#
# Adding counts for adt
#
# Adding data for adt
#
# No variable features found for adt
#
# No feature-level metadata found for adt
#
# Adding data for rna_int
#
# Adding scale.data for rna_int
#
# Adding variable features for rna_int
#
# No feature-level metadata found for rna_int
#
# Adding data for adt_int
#
# Adding scale.data for adt_int
#
# Adding variable features for adt_int
#
# No feature-level metadata found for adt_int
#
# Adding cell embeddings for pca_rpca_rna
#
# Adding loadings for pca_rpca_rna
#
# No projected loadings for pca_rpca_rna
#
# Adding standard deviations for pca_rpca_rna
#
# No JackStraw data for pca_rpca_rna
#
# Adding cell embeddings for pca_rpca_adt
#
# Adding loadings for pca_rpca_adt
#
# No projected loadings for pca_rpca_adt
#
# Adding standard deviations for pca_rpca_adt
#
# No JackStraw data for pca_rpca_adt
#
# Adding cell embeddings for umap
#
# No loadings for umap
#
# No projected loadings for umap
#
# No standard deviations for umap
#
# No JackStraw data for umap
