# %%
source("./preprocess/utils.R")
setwd("./")
library(mclust)
library(RColorBrewer)

parser <- ArgumentParser()
parser$add_argument("--task", type = "character", default = "atlas_tissues_cl")
parser$add_argument("--method", type = "character", default = "midas_embed")
parser$add_argument("--experiment", type = "character", default = "c_3")
parser$add_argument("--model", type = "character", default = "default")
parser$add_argument("--reference", type = "character", default = "atlas_new")
parser$add_argument("--init_model", type = "character", default = "")
o <- parser$parse_known_args()[[1]]

config <- parseTOML("configs/data.toml")[[gsub("_transfer$|_ref_.*$", "", o$task)]]
config_ref <- parseTOML("configs/data.toml")[[gsub("_transfer$|_ref_.*$", "", o$reference)]]
config$raw_data_dirs <- c(config_ref$raw_data_dirs, config$raw_data_dirs)
subset_names <- basename(config$raw_data_dirs)
subset_ids <- sapply(seq_along(subset_names) - 1, toString)
input_dirs <- pj("result", o$task, o$experiment, o$model, "predict", o$init_model, paste0("subset_", subset_ids))
pp_dir <- pj("data", "processed", o$reference)
output_dir <- pj("result", "comparison", o$task, o$method, o$experiment, o$model, o$init_model)
mkdir(output_dir, remove_old = F)
label_paths <- pj(config$raw_data_dirs, "label_seurat_cca", "l1.csv")

K <- parseTOML("configs/model.toml")[["default"]]$dim_c
l <- 7.5  # figure size
L <- 10   # figure size
m <- 0.5  # legend margin

# %%
z_list <- list()
cell_name_list <- list()
label_list <- list()
is_label <- T
subset_name_list <- list()
S <- length(subset_names)
for (i in seq_along(subset_names)) {
    subset_name <- subset_names[i]
    z_dir    <- pj(input_dirs[i], "z", "joint")
    fnames <- dir(path = z_dir, pattern = ".csv$")
    fnames <- str_sort(fnames, decreasing = F)

    z_subset_list <- list()
    N <- length(fnames)
    for (n in seq_along(fnames)) {
        message(paste0("Loading Subset ", i, "/", S, ", File ", n, "/", N))
        z_subset_list[[n]] <- read.csv(file.path(z_dir, fnames[n]), header = F)
    }
    z_list[[subset_name]] <- bind_rows(z_subset_list)

    if (i < 35) {
        cell_name_list[[subset_name]] <- read.csv(pj(pp_dir, paste0("subset_", subset_ids[i]),
            "cell_names.csv"), header = T)[, 2]    
    } else if (i == 35) {
        cell_name_list[[subset_name]] <- read.csv(pj(pj("data", "processed", "tonsil"), paste0("subset_", '0'),
            "cell_names.csv"), header = T)[, 2]
    } else if (i == 36) {
        cell_name_list[[subset_name]] <- read.csv(pj(pj("data", "processed", "bone_marrow_02"), paste0("subset_", '0'),
            "cell_names.csv"), header = T)[, 2]
    } else if (i == 37) {
        cell_name_list[[subset_name]] <- read.csv(pj(pj("data", "processed", "spleen"), paste0("subset_", '0'),
            "cell_names.csv"), header = T)[, 2]
    }
    if (file.exists(label_paths[i])) {
        if (grepl('lane', subset_names[i])) {
            label_list[[subset_name]] <- read.csv(gsub("l1.csv", "l1_singler.csv", label_paths[i]), header = T)[, 2]
        } else {
            label_list[[subset_name]] <- read.csv(label_paths[i], header = T)[, 2]
        }
    } else {
        is_label <- F
    }
    
    subset_name_list[[subset_name]] <- rep(subset_name, length(cell_name_list[[subset_name]]))
}
# Out:
# Loading Subset 1/37, File 1/29
#
# Loading Subset 1/37, File 2/29
#
# Loading Subset 1/37, File 3/29
#
# Loading Subset 1/37, File 4/29
#
# Loading Subset 1/37, File 5/29
#
# Loading Subset 1/37, File 6/29
#
# Loading Subset 1/37, File 7/29
#
# Loading Subset 1/37, File 8/29
#
# Loading Subset 1/37, File 9/29
#
# Loading Subset 1/37, File 10/29
#
# Loading Subset 1/37, File 11/29
#
# Loading Subset 1/37, File 12/29
#
# Loading Subset 1/37, File 13/29
#
# Loading Subset 1/37, File 14/29
#
# Loading Subset 1/37, File 15/29
#
# Loading Subset 1/37, File 16/29
#
# Loading Subset 1/37, File 17/29
#
# Loading Subset 1/37, File 18/29
#
# Loading Subset 1/37, File 19/29
#
# Loading Subset 1/37, File 20/29
#
# Loading Subset 1/37, File 21/29
#
# Loading Subset 1/37, File 22/29
#
# Loading Subset 1/37, File 23/29
#
# Loading Subset 1/37, File 24/29
#
# Loading Subset 1/37, File 25/29
#
# Loading Subset 1/37, File 26/29
#
# Loading Subset 1/37, File 27/29
#
# Loading Subset 1/37, File 28/29
#
# Loading Subset 1/37, File 29/29
#
# Loading Subset 2/37, File 1/24
#
# Loading Subset 2/37, File 2/24
#
# Loading Subset 2/37, File 3/24
#
# Loading Subset 2/37, File 4/24
#
# Loading Subset 2/37, File 5/24
#
# Loading Subset 2/37, File 6/24
#
# Loading Subset 2/37, File 7/24
#
# Loading Subset 2/37, File 8/24
#
# Loading Subset 2/37, File 9/24
#
# Loading Subset 2/37, File 10/24
#
# Loading Subset 2/37, File 11/24
#
# Loading Subset 2/37, File 12/24
#
# Loading Subset 2/37, File 13/24
#
# Loading Subset 2/37, File 14/24
#
# Loading Subset 2/37, File 15/24
#
# Loading Subset 2/37, File 16/24
#
# Loading Subset 2/37, File 17/24
#
# Loading Subset 2/37, File 18/24
#
# Loading Subset 2/37, File 19/24
#
# Loading Subset 2/37, File 20/24
#
# Loading Subset 2/37, File 21/24
#
# Loading Subset 2/37, File 22/24
#
# Loading Subset 2/37, File 23/24
#
# Loading Subset 2/37, File 24/24
#
# Loading Subset 3/37, File 1/40
#
# Loading Subset 3/37, File 2/40
#
# Loading Subset 3/37, File 3/40
#
# Loading Subset 3/37, File 4/40
#
# Loading Subset 3/37, File 5/40
#
# Loading Subset 3/37, File 6/40
#
# Loading Subset 3/37, File 7/40
#
# Loading Subset 3/37, File 8/40
#
# Loading Subset 3/37, File 9/40
#
# Loading Subset 3/37, File 10/40
#
# Loading Subset 3/37, File 11/40
#
# Loading Subset 3/37, File 12/40
#
# Loading Subset 3/37, File 13/40
#
# Loading Subset 3/37, File 14/40
#
# Loading Subset 3/37, File 15/40
#
# Loading Subset 3/37, File 16/40
#
# Loading Subset 3/37, File 17/40
#
# Loading Subset 3/37, File 18/40
#
# Loading Subset 3/37, File 19/40
#
# Loading Subset 3/37, File 20/40
#
# Loading Subset 3/37, File 21/40
#
# Loading Subset 3/37, File 22/40
#
# Loading Subset 3/37, File 23/40
#
# Loading Subset 3/37, File 24/40
#
# Loading Subset 3/37, File 25/40
#
# Loading Subset 3/37, File 26/40
#
# Loading Subset 3/37, File 27/40
#
# Loading Subset 3/37, File 28/40
#
# Loading Subset 3/37, File 29/40
#
# Loading Subset 3/37, File 30/40
#
# Loading Subset 3/37, File 31/40
#
# Loading Subset 3/37, File 32/40
#
# Loading Subset 3/37, File 33/40
#
# Loading Subset 3/37, File 34/40
#
# Loading Subset 3/37, File 35/40
#
# Loading Subset 3/37, File 36/40
#
# Loading Subset 3/37, File 37/40
#
# Loading Subset 3/37, File 38/40
#
# Loading Subset 3/37, File 39/40
#
# Loading Subset 3/37, File 40/40
#
# Loading Subset 4/37, File 1/38
#
# Loading Subset 4/37, File 2/38
#
# Loading Subset 4/37, File 3/38
#
# Loading Subset 4/37, File 4/38
#
# Loading Subset 4/37, File 5/38
#
# Loading Subset 4/37, File 6/38
#
# Loading Subset 4/37, File 7/38
#
# Loading Subset 4/37, File 8/38
#
# Loading Subset 4/37, File 9/38
#
# Loading Subset 4/37, File 10/38
#
# Loading Subset 4/37, File 11/38
#
# Loading Subset 4/37, File 12/38
#
# Loading Subset 4/37, File 13/38
#
# Loading Subset 4/37, File 14/38
#
# Loading Subset 4/37, File 15/38
#
# Loading Subset 4/37, File 16/38
#
# Loading Subset 4/37, File 17/38
#
# Loading Subset 4/37, File 18/38
#
# Loading Subset 4/37, File 19/38
#
# Loading Subset 4/37, File 20/38
#
# Loading Subset 4/37, File 21/38
#
# Loading Subset 4/37, File 22/38
#
# Loading Subset 4/37, File 23/38
#
# Loading Subset 4/37, File 24/38
#
# Loading Subset 4/37, File 25/38
#
# Loading Subset 4/37, File 26/38
#
# Loading Subset 4/37, File 27/38
#
# Loading Subset 4/37, File 28/38
#
# Loading Subset 4/37, File 29/38
#
# Loading Subset 4/37, File 30/38
#
# Loading Subset 4/37, File 31/38
#
# Loading Subset 4/37, File 32/38
#
# Loading Subset 4/37, File 33/38
#
# Loading Subset 4/37, File 34/38
#
# Loading Subset 4/37, File 35/38
#
# Loading Subset 4/37, File 36/38
#
# Loading Subset 4/37, File 37/38
#
# Loading Subset 4/37, File 38/38
#
# Loading Subset 5/37, File 1/29
#
# Loading Subset 5/37, File 2/29
#
# Loading Subset 5/37, File 3/29
#
# Loading Subset 5/37, File 4/29
#
# Loading Subset 5/37, File 5/29
#
# Loading Subset 5/37, File 6/29
#
# Loading Subset 5/37, File 7/29
#
# Loading Subset 5/37, File 8/29
#
# Loading Subset 5/37, File 9/29
#
# Loading Subset 5/37, File 10/29
#
# Loading Subset 5/37, File 11/29
#
# Loading Subset 5/37, File 12/29
#
# Loading Subset 5/37, File 13/29
#
# Loading Subset 5/37, File 14/29
#
# Loading Subset 5/37, File 15/29
#
# Loading Subset 5/37, File 16/29
#
# Loading Subset 5/37, File 17/29
#
# Loading Subset 5/37, File 18/29
#
# Loading Subset 5/37, File 19/29
#
# Loading Subset 5/37, File 20/29
#
# Loading Subset 5/37, File 21/29
#
# Loading Subset 5/37, File 22/29
#
# Loading Subset 5/37, File 23/29
#
# Loading Subset 5/37, File 24/29
#
# Loading Subset 5/37, File 25/29
#
# Loading Subset 5/37, File 26/29
#
# Loading Subset 5/37, File 27/29
#
# Loading Subset 5/37, File 28/29
#
# Loading Subset 5/37, File 29/29
#
# Loading Subset 6/37, File 1/26
#
# Loading Subset 6/37, File 2/26
#
# Loading Subset 6/37, File 3/26
#
# Loading Subset 6/37, File 4/26
#
# Loading Subset 6/37, File 5/26
#
# Loading Subset 6/37, File 6/26
#
# Loading Subset 6/37, File 7/26
#
# Loading Subset 6/37, File 8/26
#
# Loading Subset 6/37, File 9/26
#
# Loading Subset 6/37, File 10/26
#
# Loading Subset 6/37, File 11/26
#
# Loading Subset 6/37, File 12/26
#
# Loading Subset 6/37, File 13/26
#
# Loading Subset 6/37, File 14/26
#
# Loading Subset 6/37, File 15/26
#
# Loading Subset 6/37, File 16/26
#
# Loading Subset 6/37, File 17/26
#
# Loading Subset 6/37, File 18/26
#
# Loading Subset 6/37, File 19/26
#
# Loading Subset 6/37, File 20/26
#
# Loading Subset 6/37, File 21/26
#
# Loading Subset 6/37, File 22/26
#
# Loading Subset 6/37, File 23/26
#
# Loading Subset 6/37, File 24/26
#
# Loading Subset 6/37, File 25/26
#
# Loading Subset 6/37, File 26/26
#
# Loading Subset 7/37, File 1/27
#
# Loading Subset 7/37, File 2/27
#
# Loading Subset 7/37, File 3/27
#
# Loading Subset 7/37, File 4/27
#
# Loading Subset 7/37, File 5/27
#
# Loading Subset 7/37, File 6/27
#
# Loading Subset 7/37, File 7/27
#
# Loading Subset 7/37, File 8/27
#
# Loading Subset 7/37, File 9/27
#
# Loading Subset 7/37, File 10/27
#
# Loading Subset 7/37, File 11/27
#
# Loading Subset 7/37, File 12/27
#
# Loading Subset 7/37, File 13/27
#
# Loading Subset 7/37, File 14/27
#
# Loading Subset 7/37, File 15/27
#
# Loading Subset 7/37, File 16/27
#
# Loading Subset 7/37, File 17/27
#
# Loading Subset 7/37, File 18/27
#
# Loading Subset 7/37, File 19/27
#
# Loading Subset 7/37, File 20/27
#
# Loading Subset 7/37, File 21/27
#
# Loading Subset 7/37, File 22/27
#
# Loading Subset 7/37, File 23/27
#
# Loading Subset 7/37, File 24/27
#
# Loading Subset 7/37, File 25/27
#
# Loading Subset 7/37, File 26/27
#
# Loading Subset 7/37, File 27/27
#
# Loading Subset 8/37, File 1/27
#
# Loading Subset 8/37, File 2/27
#
# Loading Subset 8/37, File 3/27
#
# Loading Subset 8/37, File 4/27
#
# Loading Subset 8/37, File 5/27
#
# Loading Subset 8/37, File 6/27
#
# Loading Subset 8/37, File 7/27
#
# Loading Subset 8/37, File 8/27
#
# Loading Subset 8/37, File 9/27
#
# Loading Subset 8/37, File 10/27
#
# Loading Subset 8/37, File 11/27
#
# Loading Subset 8/37, File 12/27
#
# Loading Subset 8/37, File 13/27
#
# Loading Subset 8/37, File 14/27
#
# Loading Subset 8/37, File 15/27
#
# Loading Subset 8/37, File 16/27
#
# Loading Subset 8/37, File 17/27
#
# Loading Subset 8/37, File 18/27
#
# Loading Subset 8/37, File 19/27
#
# Loading Subset 8/37, File 20/27
#
# Loading Subset 8/37, File 21/27
#
# Loading Subset 8/37, File 22/27
#
# Loading Subset 8/37, File 23/27
#
# Loading Subset 8/37, File 24/27
#
# Loading Subset 8/37, File 25/27
#
# Loading Subset 8/37, File 26/27
#
# Loading Subset 8/37, File 27/27
#
# Loading Subset 9/37, File 1/28
#
# Loading Subset 9/37, File 2/28
#
# Loading Subset 9/37, File 3/28
#
# Loading Subset 9/37, File 4/28
#
# Loading Subset 9/37, File 5/28
#
# Loading Subset 9/37, File 6/28
#
# Loading Subset 9/37, File 7/28
#
# Loading Subset 9/37, File 8/28
#
# Loading Subset 9/37, File 9/28
#
# Loading Subset 9/37, File 10/28
#
# Loading Subset 9/37, File 11/28
#
# Loading Subset 9/37, File 12/28
#
# Loading Subset 9/37, File 13/28
#
# Loading Subset 9/37, File 14/28
#
# Loading Subset 9/37, File 15/28
#
# Loading Subset 9/37, File 16/28
#
# Loading Subset 9/37, File 17/28
#
# Loading Subset 9/37, File 18/28
#
# Loading Subset 9/37, File 19/28
#
# Loading Subset 9/37, File 20/28
#
# Loading Subset 9/37, File 21/28
#
# Loading Subset 9/37, File 22/28
#
# Loading Subset 9/37, File 23/28
#
# Loading Subset 9/37, File 24/28
#
# Loading Subset 9/37, File 25/28
#
# Loading Subset 9/37, File 26/28
#
# Loading Subset 9/37, File 27/28
#
# Loading Subset 9/37, File 28/28
#
# Loading Subset 10/37, File 1/24
#
# Loading Subset 10/37, File 2/24
#
# Loading Subset 10/37, File 3/24
#
# Loading Subset 10/37, File 4/24
#
# Loading Subset 10/37, File 5/24
#
# Loading Subset 10/37, File 6/24
#
# Loading Subset 10/37, File 7/24
#
# Loading Subset 10/37, File 8/24
#
# Loading Subset 10/37, File 9/24
#
# Loading Subset 10/37, File 10/24
#
# Loading Subset 10/37, File 11/24
#
# Loading Subset 10/37, File 12/24
#
# Loading Subset 10/37, File 13/24
#
# Loading Subset 10/37, File 14/24
#
# Loading Subset 10/37, File 15/24
#
# Loading Subset 10/37, File 16/24
#
# Loading Subset 10/37, File 17/24
#
# Loading Subset 10/37, File 18/24
#
# Loading Subset 10/37, File 19/24
#
# Loading Subset 10/37, File 20/24
#
# Loading Subset 10/37, File 21/24
#
# Loading Subset 10/37, File 22/24
#
# Loading Subset 10/37, File 23/24
#
# Loading Subset 10/37, File 24/24
#
# Loading Subset 11/37, File 1/29
#
# Loading Subset 11/37, File 2/29
#
# Loading Subset 11/37, File 3/29
#
# Loading Subset 11/37, File 4/29
#
# Loading Subset 11/37, File 5/29
#
# Loading Subset 11/37, File 6/29
#
# Loading Subset 11/37, File 7/29
#
# Loading Subset 11/37, File 8/29
#
# Loading Subset 11/37, File 9/29
#
# Loading Subset 11/37, File 10/29
#
# Loading Subset 11/37, File 11/29
#
# Loading Subset 11/37, File 12/29
#
# Loading Subset 11/37, File 13/29
#
# Loading Subset 11/37, File 14/29
#
# Loading Subset 11/37, File 15/29
#
# Loading Subset 11/37, File 16/29
#
# Loading Subset 11/37, File 17/29
#
# Loading Subset 11/37, File 18/29
#
# Loading Subset 11/37, File 19/29
#
# Loading Subset 11/37, File 20/29
#
# Loading Subset 11/37, File 21/29
#
# Loading Subset 11/37, File 22/29
#
# Loading Subset 11/37, File 23/29
#
# Loading Subset 11/37, File 24/29
#
# Loading Subset 11/37, File 25/29
#
# Loading Subset 11/37, File 26/29
#
# Loading Subset 11/37, File 27/29
#
# Loading Subset 11/37, File 28/29
#
# Loading Subset 11/37, File 29/29
#
# Loading Subset 12/37, File 1/39
#
# Loading Subset 12/37, File 2/39
#
# Loading Subset 12/37, File 3/39
#
# Loading Subset 12/37, File 4/39
#
# Loading Subset 12/37, File 5/39
#
# Loading Subset 12/37, File 6/39
#
# Loading Subset 12/37, File 7/39
#
# Loading Subset 12/37, File 8/39
#
# Loading Subset 12/37, File 9/39
#
# Loading Subset 12/37, File 10/39
#
# Loading Subset 12/37, File 11/39
#
# Loading Subset 12/37, File 12/39
#
# Loading Subset 12/37, File 13/39
#
# Loading Subset 12/37, File 14/39
#
# Loading Subset 12/37, File 15/39
#
# Loading Subset 12/37, File 16/39
#
# Loading Subset 12/37, File 17/39
#
# Loading Subset 12/37, File 18/39
#
# Loading Subset 12/37, File 19/39
#
# Loading Subset 12/37, File 20/39
#
# Loading Subset 12/37, File 21/39
#
# Loading Subset 12/37, File 22/39
#
# Loading Subset 12/37, File 23/39
#
# Loading Subset 12/37, File 24/39
#
# Loading Subset 12/37, File 25/39
#
# Loading Subset 12/37, File 26/39
#
# Loading Subset 12/37, File 27/39
#
# Loading Subset 12/37, File 28/39
#
# Loading Subset 12/37, File 29/39
#
# Loading Subset 12/37, File 30/39
#
# Loading Subset 12/37, File 31/39
#
# Loading Subset 12/37, File 32/39
#
# Loading Subset 12/37, File 33/39
#
# Loading Subset 12/37, File 34/39
#
# Loading Subset 12/37, File 35/39
#
# Loading Subset 12/37, File 36/39
#
# Loading Subset 12/37, File 37/39
#
# Loading Subset 12/37, File 38/39
#
# Loading Subset 12/37, File 39/39
#
# Loading Subset 13/37, File 1/38
#
# Loading Subset 13/37, File 2/38
#
# Loading Subset 13/37, File 3/38
#
# Loading Subset 13/37, File 4/38
#
# Loading Subset 13/37, File 5/38
#
# Loading Subset 13/37, File 6/38
#
# Loading Subset 13/37, File 7/38
#
# Loading Subset 13/37, File 8/38
#
# Loading Subset 13/37, File 9/38
#
# Loading Subset 13/37, File 10/38
#
# Loading Subset 13/37, File 11/38
#
# Loading Subset 13/37, File 12/38
#
# Loading Subset 13/37, File 13/38
#
# Loading Subset 13/37, File 14/38
#
# Loading Subset 13/37, File 15/38
#
# Loading Subset 13/37, File 16/38
#
# Loading Subset 13/37, File 17/38
#
# Loading Subset 13/37, File 18/38
#
# Loading Subset 13/37, File 19/38
#
# Loading Subset 13/37, File 20/38
#
# Loading Subset 13/37, File 21/38
#
# Loading Subset 13/37, File 22/38
#
# Loading Subset 13/37, File 23/38
#
# Loading Subset 13/37, File 24/38
#
# Loading Subset 13/37, File 25/38
#
# Loading Subset 13/37, File 26/38
#
# Loading Subset 13/37, File 27/38
#
# Loading Subset 13/37, File 28/38
#
# Loading Subset 13/37, File 29/38
#
# Loading Subset 13/37, File 30/38
#
# Loading Subset 13/37, File 31/38
#
# Loading Subset 13/37, File 32/38
#
# Loading Subset 13/37, File 33/38
#
# Loading Subset 13/37, File 34/38
#
# Loading Subset 13/37, File 35/38
#
# Loading Subset 13/37, File 36/38
#
# Loading Subset 13/37, File 37/38
#
# Loading Subset 13/37, File 38/38
#
# Loading Subset 14/37, File 1/44
#
# Loading Subset 14/37, File 2/44
#
# Loading Subset 14/37, File 3/44
#
# Loading Subset 14/37, File 4/44
#
# Loading Subset 14/37, File 5/44
#
# Loading Subset 14/37, File 6/44
#
# Loading Subset 14/37, File 7/44
#
# Loading Subset 14/37, File 8/44
#
# Loading Subset 14/37, File 9/44
#
# Loading Subset 14/37, File 10/44
#
# Loading Subset 14/37, File 11/44
#
# Loading Subset 14/37, File 12/44
#
# Loading Subset 14/37, File 13/44
#
# Loading Subset 14/37, File 14/44
#
# Loading Subset 14/37, File 15/44
#
# Loading Subset 14/37, File 16/44
#
# Loading Subset 14/37, File 17/44
#
# Loading Subset 14/37, File 18/44
#
# Loading Subset 14/37, File 19/44
#
# Loading Subset 14/37, File 20/44
#
# Loading Subset 14/37, File 21/44
#
# Loading Subset 14/37, File 22/44
#
# Loading Subset 14/37, File 23/44
#
# Loading Subset 14/37, File 24/44
#
# Loading Subset 14/37, File 25/44
#
# Loading Subset 14/37, File 26/44
#
# Loading Subset 14/37, File 27/44
#
# Loading Subset 14/37, File 28/44
#
# Loading Subset 14/37, File 29/44
#
# Loading Subset 14/37, File 30/44
#
# Loading Subset 14/37, File 31/44
#
# Loading Subset 14/37, File 32/44
#
# Loading Subset 14/37, File 33/44
#
# Loading Subset 14/37, File 34/44
#
# Loading Subset 14/37, File 35/44
#
# Loading Subset 14/37, File 36/44
#
# Loading Subset 14/37, File 37/44
#
# Loading Subset 14/37, File 38/44
#
# Loading Subset 14/37, File 39/44
#
# Loading Subset 14/37, File 40/44
#
# Loading Subset 14/37, File 41/44
#
# Loading Subset 14/37, File 42/44
#
# Loading Subset 14/37, File 43/44
#
# Loading Subset 14/37, File 44/44
#
# Loading Subset 15/37, File 1/11
#
# Loading Subset 15/37, File 2/11
#
# Loading Subset 15/37, File 3/11
#
# Loading Subset 15/37, File 4/11
#
# Loading Subset 15/37, File 5/11
#
# Loading Subset 15/37, File 6/11
#
# Loading Subset 15/37, File 7/11
#
# Loading Subset 15/37, File 8/11
#
# Loading Subset 15/37, File 9/11
#
# Loading Subset 15/37, File 10/11
#
# Loading Subset 15/37, File 11/11
#
# Loading Subset 16/37, File 1/17
#
# Loading Subset 16/37, File 2/17
#
# Loading Subset 16/37, File 3/17
#
# Loading Subset 16/37, File 4/17
#
# Loading Subset 16/37, File 5/17
#
# Loading Subset 16/37, File 6/17
#
# Loading Subset 16/37, File 7/17
#
# Loading Subset 16/37, File 8/17
#
# Loading Subset 16/37, File 9/17
#
# Loading Subset 16/37, File 10/17
#
# Loading Subset 16/37, File 11/17
#
# Loading Subset 16/37, File 12/17
#
# Loading Subset 16/37, File 13/17
#
# Loading Subset 16/37, File 14/17
#
# Loading Subset 16/37, File 15/17
#
# Loading Subset 16/37, File 16/17
#
# Loading Subset 16/37, File 17/17
#
# Loading Subset 17/37, File 1/21
#
# Loading Subset 17/37, File 2/21
#
# Loading Subset 17/37, File 3/21
#
# Loading Subset 17/37, File 4/21
#
# Loading Subset 17/37, File 5/21
#
# Loading Subset 17/37, File 6/21
#
# Loading Subset 17/37, File 7/21
#
# Loading Subset 17/37, File 8/21
#
# Loading Subset 17/37, File 9/21
#
# Loading Subset 17/37, File 10/21
#
# Loading Subset 17/37, File 11/21
#
# Loading Subset 17/37, File 12/21
#
# Loading Subset 17/37, File 13/21
#
# Loading Subset 17/37, File 14/21
#
# Loading Subset 17/37, File 15/21
#
# Loading Subset 17/37, File 16/21
#
# Loading Subset 17/37, File 17/21
#
# Loading Subset 17/37, File 18/21
#
# Loading Subset 17/37, File 19/21
#
# Loading Subset 17/37, File 20/21
#
# Loading Subset 17/37, File 21/21
#
# Loading Subset 18/37, File 1/20
#
# Loading Subset 18/37, File 2/20
#
# Loading Subset 18/37, File 3/20
#
# Loading Subset 18/37, File 4/20
#
# Loading Subset 18/37, File 5/20
#
# Loading Subset 18/37, File 6/20
#
# Loading Subset 18/37, File 7/20
#
# Loading Subset 18/37, File 8/20
#
# Loading Subset 18/37, File 9/20
#
# Loading Subset 18/37, File 10/20
#
# Loading Subset 18/37, File 11/20
#
# Loading Subset 18/37, File 12/20
#
# Loading Subset 18/37, File 13/20
#
# Loading Subset 18/37, File 14/20
#
# Loading Subset 18/37, File 15/20
#
# Loading Subset 18/37, File 16/20
#
# Loading Subset 18/37, File 17/20
#
# Loading Subset 18/37, File 18/20
#
# Loading Subset 18/37, File 19/20
#
# Loading Subset 18/37, File 20/20
#
# Loading Subset 19/37, File 1/15
#
# Loading Subset 19/37, File 2/15
#
# Loading Subset 19/37, File 3/15
#
# Loading Subset 19/37, File 4/15
#
# Loading Subset 19/37, File 5/15
#
# Loading Subset 19/37, File 6/15
#
# Loading Subset 19/37, File 7/15
#
# Loading Subset 19/37, File 8/15
#
# Loading Subset 19/37, File 9/15
#
# Loading Subset 19/37, File 10/15
#
# Loading Subset 19/37, File 11/15
#
# Loading Subset 19/37, File 12/15
#
# Loading Subset 19/37, File 13/15
#
# Loading Subset 19/37, File 14/15
#
# Loading Subset 19/37, File 15/15
#
# Loading Subset 20/37, File 1/25
#
# Loading Subset 20/37, File 2/25
#
# Loading Subset 20/37, File 3/25
#
# Loading Subset 20/37, File 4/25
#
# Loading Subset 20/37, File 5/25
#
# Loading Subset 20/37, File 6/25
#
# Loading Subset 20/37, File 7/25
#
# Loading Subset 20/37, File 8/25
#
# Loading Subset 20/37, File 9/25
#
# Loading Subset 20/37, File 10/25
#
# Loading Subset 20/37, File 11/25
#
# Loading Subset 20/37, File 12/25
#
# Loading Subset 20/37, File 13/25
#
# Loading Subset 20/37, File 14/25
#
# Loading Subset 20/37, File 15/25
#
# Loading Subset 20/37, File 16/25
#
# Loading Subset 20/37, File 17/25
#
# Loading Subset 20/37, File 18/25
#
# Loading Subset 20/37, File 19/25
#
# Loading Subset 20/37, File 20/25
#
# Loading Subset 20/37, File 21/25
#
# Loading Subset 20/37, File 22/25
#
# Loading Subset 20/37, File 23/25
#
# Loading Subset 20/37, File 24/25
#
# Loading Subset 20/37, File 25/25
#
# Loading Subset 21/37, File 1/24
#
# Loading Subset 21/37, File 2/24
#
# Loading Subset 21/37, File 3/24
#
# Loading Subset 21/37, File 4/24
#
# Loading Subset 21/37, File 5/24
#
# Loading Subset 21/37, File 6/24
#
# Loading Subset 21/37, File 7/24
#
# Loading Subset 21/37, File 8/24
#
# Loading Subset 21/37, File 9/24
#
# Loading Subset 21/37, File 10/24
#
# Loading Subset 21/37, File 11/24
#
# Loading Subset 21/37, File 12/24
#
# Loading Subset 21/37, File 13/24
#
# Loading Subset 21/37, File 14/24
#
# Loading Subset 21/37, File 15/24
#
# Loading Subset 21/37, File 16/24
#
# Loading Subset 21/37, File 17/24
#
# Loading Subset 21/37, File 18/24
#
# Loading Subset 21/37, File 19/24
#
# Loading Subset 21/37, File 20/24
#
# Loading Subset 21/37, File 21/24
#
# Loading Subset 21/37, File 22/24
#
# Loading Subset 21/37, File 23/24
#
# Loading Subset 21/37, File 24/24
#
# Loading Subset 22/37, File 1/19
#
# Loading Subset 22/37, File 2/19
#
# Loading Subset 22/37, File 3/19
#
# Loading Subset 22/37, File 4/19
#
# Loading Subset 22/37, File 5/19
#
# Loading Subset 22/37, File 6/19
#
# Loading Subset 22/37, File 7/19
#
# Loading Subset 22/37, File 8/19
#
# Loading Subset 22/37, File 9/19
#
# Loading Subset 22/37, File 10/19
#
# Loading Subset 22/37, File 11/19
#
# Loading Subset 22/37, File 12/19
#
# Loading Subset 22/37, File 13/19
#
# Loading Subset 22/37, File 14/19
#
# Loading Subset 22/37, File 15/19
#
# Loading Subset 22/37, File 16/19
#
# Loading Subset 22/37, File 17/19
#
# Loading Subset 22/37, File 18/19
#
# Loading Subset 22/37, File 19/19
#
# Loading Subset 23/37, File 1/21
#
# Loading Subset 23/37, File 2/21
#
# Loading Subset 23/37, File 3/21
#
# Loading Subset 23/37, File 4/21
#
# Loading Subset 23/37, File 5/21
#
# Loading Subset 23/37, File 6/21
#
# Loading Subset 23/37, File 7/21
#
# Loading Subset 23/37, File 8/21
#
# Loading Subset 23/37, File 9/21
#
# Loading Subset 23/37, File 10/21
#
# Loading Subset 23/37, File 11/21
#
# Loading Subset 23/37, File 12/21
#
# Loading Subset 23/37, File 13/21
#
# Loading Subset 23/37, File 14/21
#
# Loading Subset 23/37, File 15/21
#
# Loading Subset 23/37, File 16/21
#
# Loading Subset 23/37, File 17/21
#
# Loading Subset 23/37, File 18/21
#
# Loading Subset 23/37, File 19/21
#
# Loading Subset 23/37, File 20/21
#
# Loading Subset 23/37, File 21/21
#
# Loading Subset 24/37, File 1/28
#
# Loading Subset 24/37, File 2/28
#
# Loading Subset 24/37, File 3/28
#
# Loading Subset 24/37, File 4/28
#
# Loading Subset 24/37, File 5/28
#
# Loading Subset 24/37, File 6/28
#
# Loading Subset 24/37, File 7/28
#
# Loading Subset 24/37, File 8/28
#
# Loading Subset 24/37, File 9/28
#
# Loading Subset 24/37, File 10/28
#
# Loading Subset 24/37, File 11/28
#
# Loading Subset 24/37, File 12/28
#
# Loading Subset 24/37, File 13/28
#
# Loading Subset 24/37, File 14/28
#
# Loading Subset 24/37, File 15/28
#
# Loading Subset 24/37, File 16/28
#
# Loading Subset 24/37, File 17/28
#
# Loading Subset 24/37, File 18/28
#
# Loading Subset 24/37, File 19/28
#
# Loading Subset 24/37, File 20/28
#
# Loading Subset 24/37, File 21/28
#
# Loading Subset 24/37, File 22/28
#
# Loading Subset 24/37, File 23/28
#
# Loading Subset 24/37, File 24/28
#
# Loading Subset 24/37, File 25/28
#
# Loading Subset 24/37, File 26/28
#
# Loading Subset 24/37, File 27/28
#
# Loading Subset 24/37, File 28/28
#
# Loading Subset 25/37, File 1/24
#
# Loading Subset 25/37, File 2/24
#
# Loading Subset 25/37, File 3/24
#
# Loading Subset 25/37, File 4/24
#
# Loading Subset 25/37, File 5/24
#
# Loading Subset 25/37, File 6/24
#
# Loading Subset 25/37, File 7/24
#
# Loading Subset 25/37, File 8/24
#
# Loading Subset 25/37, File 9/24
#
# Loading Subset 25/37, File 10/24
#
# Loading Subset 25/37, File 11/24
#
# Loading Subset 25/37, File 12/24
#
# Loading Subset 25/37, File 13/24
#
# Loading Subset 25/37, File 14/24
#
# Loading Subset 25/37, File 15/24
#
# Loading Subset 25/37, File 16/24
#
# Loading Subset 25/37, File 17/24
#
# Loading Subset 25/37, File 18/24
#
# Loading Subset 25/37, File 19/24
#
# Loading Subset 25/37, File 20/24
#
# Loading Subset 25/37, File 21/24
#
# Loading Subset 25/37, File 22/24
#
# Loading Subset 25/37, File 23/24
#
# Loading Subset 25/37, File 24/24
#
# Loading Subset 26/37, File 1/35
#
# Loading Subset 26/37, File 2/35
#
# Loading Subset 26/37, File 3/35
#
# Loading Subset 26/37, File 4/35
#
# Loading Subset 26/37, File 5/35
#
# Loading Subset 26/37, File 6/35
#
# Loading Subset 26/37, File 7/35
#
# Loading Subset 26/37, File 8/35
#
# Loading Subset 26/37, File 9/35
#
# Loading Subset 26/37, File 10/35
#
# Loading Subset 26/37, File 11/35
#
# Loading Subset 26/37, File 12/35
#
# Loading Subset 26/37, File 13/35
#
# Loading Subset 26/37, File 14/35
#
# Loading Subset 26/37, File 15/35
#
# Loading Subset 26/37, File 16/35
#
# Loading Subset 26/37, File 17/35
#
# Loading Subset 26/37, File 18/35
#
# Loading Subset 26/37, File 19/35
#
# Loading Subset 26/37, File 20/35
#
# Loading Subset 26/37, File 21/35
#
# Loading Subset 26/37, File 22/35
#
# Loading Subset 26/37, File 23/35
#
# Loading Subset 26/37, File 24/35
#
# Loading Subset 26/37, File 25/35
#
# Loading Subset 26/37, File 26/35
#
# Loading Subset 26/37, File 27/35
#
# Loading Subset 26/37, File 28/35
#
# Loading Subset 26/37, File 29/35
#
# Loading Subset 26/37, File 30/35
#
# Loading Subset 26/37, File 31/35
#
# Loading Subset 26/37, File 32/35
#
# Loading Subset 26/37, File 33/35
#
# Loading Subset 26/37, File 34/35
#
# Loading Subset 26/37, File 35/35
#
# Loading Subset 27/37, File 1/35
#
# Loading Subset 27/37, File 2/35
#
# Loading Subset 27/37, File 3/35
#
# Loading Subset 27/37, File 4/35
#
# Loading Subset 27/37, File 5/35
#
# Loading Subset 27/37, File 6/35
#
# Loading Subset 27/37, File 7/35
#
# Loading Subset 27/37, File 8/35
#
# Loading Subset 27/37, File 9/35
#
# Loading Subset 27/37, File 10/35
#
# Loading Subset 27/37, File 11/35
#
# Loading Subset 27/37, File 12/35
#
# Loading Subset 27/37, File 13/35
#
# Loading Subset 27/37, File 14/35
#
# Loading Subset 27/37, File 15/35
#
# Loading Subset 27/37, File 16/35
#
# Loading Subset 27/37, File 17/35
#
# Loading Subset 27/37, File 18/35
#
# Loading Subset 27/37, File 19/35
#
# Loading Subset 27/37, File 20/35
#
# Loading Subset 27/37, File 21/35
#
# Loading Subset 27/37, File 22/35
#
# Loading Subset 27/37, File 23/35
#
# Loading Subset 27/37, File 24/35
#
# Loading Subset 27/37, File 25/35
#
# Loading Subset 27/37, File 26/35
#
# Loading Subset 27/37, File 27/35
#
# Loading Subset 27/37, File 28/35
#
# Loading Subset 27/37, File 29/35
#
# Loading Subset 27/37, File 30/35
#
# Loading Subset 27/37, File 31/35
#
# Loading Subset 27/37, File 32/35
#
# Loading Subset 27/37, File 33/35
#
# Loading Subset 27/37, File 34/35
#
# Loading Subset 27/37, File 35/35
#
# Loading Subset 28/37, File 1/22
#
# Loading Subset 28/37, File 2/22
#
# Loading Subset 28/37, File 3/22
#
# Loading Subset 28/37, File 4/22
#
# Loading Subset 28/37, File 5/22
#
# Loading Subset 28/37, File 6/22
#
# Loading Subset 28/37, File 7/22
#
# Loading Subset 28/37, File 8/22
#
# Loading Subset 28/37, File 9/22
#
# Loading Subset 28/37, File 10/22
#
# Loading Subset 28/37, File 11/22
#
# Loading Subset 28/37, File 12/22
#
# Loading Subset 28/37, File 13/22
#
# Loading Subset 28/37, File 14/22
#
# Loading Subset 28/37, File 15/22
#
# Loading Subset 28/37, File 16/22
#
# Loading Subset 28/37, File 17/22
#
# Loading Subset 28/37, File 18/22
#
# Loading Subset 28/37, File 19/22
#
# Loading Subset 28/37, File 20/22
#
# Loading Subset 28/37, File 21/22
#
# Loading Subset 28/37, File 22/22
#
# Loading Subset 29/37, File 1/20
#
# Loading Subset 29/37, File 2/20
#
# Loading Subset 29/37, File 3/20
#
# Loading Subset 29/37, File 4/20
#
# Loading Subset 29/37, File 5/20
#
# Loading Subset 29/37, File 6/20
#
# Loading Subset 29/37, File 7/20
#
# Loading Subset 29/37, File 8/20
#
# Loading Subset 29/37, File 9/20
#
# Loading Subset 29/37, File 10/20
#
# Loading Subset 29/37, File 11/20
#
# Loading Subset 29/37, File 12/20
#
# Loading Subset 29/37, File 13/20
#
# Loading Subset 29/37, File 14/20
#
# Loading Subset 29/37, File 15/20
#
# Loading Subset 29/37, File 16/20
#
# Loading Subset 29/37, File 17/20
#
# Loading Subset 29/37, File 18/20
#
# Loading Subset 29/37, File 19/20
#
# Loading Subset 29/37, File 20/20
#
# Loading Subset 30/37, File 1/47
#
# Loading Subset 30/37, File 2/47
#
# Loading Subset 30/37, File 3/47
#
# Loading Subset 30/37, File 4/47
#
# Loading Subset 30/37, File 5/47
#
# Loading Subset 30/37, File 6/47
#
# Loading Subset 30/37, File 7/47
#
# Loading Subset 30/37, File 8/47
#
# Loading Subset 30/37, File 9/47
#
# Loading Subset 30/37, File 10/47
#
# Loading Subset 30/37, File 11/47
#
# Loading Subset 30/37, File 12/47
#
# Loading Subset 30/37, File 13/47
#
# Loading Subset 30/37, File 14/47
#
# Loading Subset 30/37, File 15/47
#
# Loading Subset 30/37, File 16/47
#
# Loading Subset 30/37, File 17/47
#
# Loading Subset 30/37, File 18/47
#
# Loading Subset 30/37, File 19/47
#
# Loading Subset 30/37, File 20/47
#
# Loading Subset 30/37, File 21/47
#
# Loading Subset 30/37, File 22/47
#
# Loading Subset 30/37, File 23/47
#
# Loading Subset 30/37, File 24/47
#
# Loading Subset 30/37, File 25/47
#
# Loading Subset 30/37, File 26/47
#
# Loading Subset 30/37, File 27/47
#
# Loading Subset 30/37, File 28/47
#
# Loading Subset 30/37, File 29/47
#
# Loading Subset 30/37, File 30/47
#
# Loading Subset 30/37, File 31/47
#
# Loading Subset 30/37, File 32/47
#
# Loading Subset 30/37, File 33/47
#
# Loading Subset 30/37, File 34/47
#
# Loading Subset 30/37, File 35/47
#
# Loading Subset 30/37, File 36/47
#
# Loading Subset 30/37, File 37/47
#
# Loading Subset 30/37, File 38/47
#
# Loading Subset 30/37, File 39/47
#
# Loading Subset 30/37, File 40/47
#
# Loading Subset 30/37, File 41/47
#
# Loading Subset 30/37, File 42/47
#
# Loading Subset 30/37, File 43/47
#
# Loading Subset 30/37, File 44/47
#
# Loading Subset 30/37, File 45/47
#
# Loading Subset 30/37, File 46/47
#
# Loading Subset 30/37, File 47/47
#
# Loading Subset 31/37, File 1/58
#
# Loading Subset 31/37, File 2/58
#
# Loading Subset 31/37, File 3/58
#
# Loading Subset 31/37, File 4/58
#
# Loading Subset 31/37, File 5/58
#
# Loading Subset 31/37, File 6/58
#
# Loading Subset 31/37, File 7/58
#
# Loading Subset 31/37, File 8/58
#
# Loading Subset 31/37, File 9/58
#
# Loading Subset 31/37, File 10/58
#
# Loading Subset 31/37, File 11/58
#
# Loading Subset 31/37, File 12/58
#
# Loading Subset 31/37, File 13/58
#
# Loading Subset 31/37, File 14/58
#
# Loading Subset 31/37, File 15/58
#
# Loading Subset 31/37, File 16/58
#
# Loading Subset 31/37, File 17/58
#
# Loading Subset 31/37, File 18/58
#
# Loading Subset 31/37, File 19/58
#
# Loading Subset 31/37, File 20/58
#
# Loading Subset 31/37, File 21/58
#
# Loading Subset 31/37, File 22/58
#
# Loading Subset 31/37, File 23/58
#
# Loading Subset 31/37, File 24/58
#
# Loading Subset 31/37, File 25/58
#
# Loading Subset 31/37, File 26/58
#
# Loading Subset 31/37, File 27/58
#
# Loading Subset 31/37, File 28/58
#
# Loading Subset 31/37, File 29/58
#
# Loading Subset 31/37, File 30/58
#
# Loading Subset 31/37, File 31/58
#
# Loading Subset 31/37, File 32/58
#
# Loading Subset 31/37, File 33/58
#
# Loading Subset 31/37, File 34/58
#
# Loading Subset 31/37, File 35/58
#
# Loading Subset 31/37, File 36/58
#
# Loading Subset 31/37, File 37/58
#
# Loading Subset 31/37, File 38/58
#
# Loading Subset 31/37, File 39/58
#
# Loading Subset 31/37, File 40/58
#
# Loading Subset 31/37, File 41/58
#
# Loading Subset 31/37, File 42/58
#
# Loading Subset 31/37, File 43/58
#
# Loading Subset 31/37, File 44/58
#
# Loading Subset 31/37, File 45/58
#
# Loading Subset 31/37, File 46/58
#
# Loading Subset 31/37, File 47/58
#
# Loading Subset 31/37, File 48/58
#
# Loading Subset 31/37, File 49/58
#
# Loading Subset 31/37, File 50/58
#
# Loading Subset 31/37, File 51/58
#
# Loading Subset 31/37, File 52/58
#
# Loading Subset 31/37, File 53/58
#
# Loading Subset 31/37, File 54/58
#
# Loading Subset 31/37, File 55/58
#
# Loading Subset 31/37, File 56/58
#
# Loading Subset 31/37, File 57/58
#
# Loading Subset 31/37, File 58/58
#
# Loading Subset 32/37, File 1/39
#
# Loading Subset 32/37, File 2/39
#
# Loading Subset 32/37, File 3/39
#
# Loading Subset 32/37, File 4/39
#
# Loading Subset 32/37, File 5/39
#
# Loading Subset 32/37, File 6/39
#
# Loading Subset 32/37, File 7/39
#
# Loading Subset 32/37, File 8/39
#
# Loading Subset 32/37, File 9/39
#
# Loading Subset 32/37, File 10/39
#
# Loading Subset 32/37, File 11/39
#
# Loading Subset 32/37, File 12/39
#
# Loading Subset 32/37, File 13/39
#
# Loading Subset 32/37, File 14/39
#
# Loading Subset 32/37, File 15/39
#
# Loading Subset 32/37, File 16/39
#
# Loading Subset 32/37, File 17/39
#
# Loading Subset 32/37, File 18/39
#
# Loading Subset 32/37, File 19/39
#
# Loading Subset 32/37, File 20/39
#
# Loading Subset 32/37, File 21/39
#
# Loading Subset 32/37, File 22/39
#
# Loading Subset 32/37, File 23/39
#
# Loading Subset 32/37, File 24/39
#
# Loading Subset 32/37, File 25/39
#
# Loading Subset 32/37, File 26/39
#
# Loading Subset 32/37, File 27/39
#
# Loading Subset 32/37, File 28/39
#
# Loading Subset 32/37, File 29/39
#
# Loading Subset 32/37, File 30/39
#
# Loading Subset 32/37, File 31/39
#
# Loading Subset 32/37, File 32/39
#
# Loading Subset 32/37, File 33/39
#
# Loading Subset 32/37, File 34/39
#
# Loading Subset 32/37, File 35/39
#
# Loading Subset 32/37, File 36/39
#
# Loading Subset 32/37, File 37/39
#
# Loading Subset 32/37, File 38/39
#
# Loading Subset 32/37, File 39/39
#
# Loading Subset 33/37, File 1/52
#
# Loading Subset 33/37, File 2/52
#
# Loading Subset 33/37, File 3/52
#
# Loading Subset 33/37, File 4/52
#
# Loading Subset 33/37, File 5/52
#
# Loading Subset 33/37, File 6/52
#
# Loading Subset 33/37, File 7/52
#
# Loading Subset 33/37, File 8/52
#
# Loading Subset 33/37, File 9/52
#
# Loading Subset 33/37, File 10/52
#
# Loading Subset 33/37, File 11/52
#
# Loading Subset 33/37, File 12/52
#
# Loading Subset 33/37, File 13/52
#
# Loading Subset 33/37, File 14/52
#
# Loading Subset 33/37, File 15/52
#
# Loading Subset 33/37, File 16/52
#
# Loading Subset 33/37, File 17/52
#
# Loading Subset 33/37, File 18/52
#
# Loading Subset 33/37, File 19/52
#
# Loading Subset 33/37, File 20/52
#
# Loading Subset 33/37, File 21/52
#
# Loading Subset 33/37, File 22/52
#
# Loading Subset 33/37, File 23/52
#
# Loading Subset 33/37, File 24/52
#
# Loading Subset 33/37, File 25/52
#
# Loading Subset 33/37, File 26/52
#
# Loading Subset 33/37, File 27/52
#
# Loading Subset 33/37, File 28/52
#
# Loading Subset 33/37, File 29/52
#
# Loading Subset 33/37, File 30/52
#
# Loading Subset 33/37, File 31/52
#
# Loading Subset 33/37, File 32/52
#
# Loading Subset 33/37, File 33/52
#
# Loading Subset 33/37, File 34/52
#
# Loading Subset 33/37, File 35/52
#
# Loading Subset 33/37, File 36/52
#
# Loading Subset 33/37, File 37/52
#
# Loading Subset 33/37, File 38/52
#
# Loading Subset 33/37, File 39/52
#
# Loading Subset 33/37, File 40/52
#
# Loading Subset 33/37, File 41/52
#
# Loading Subset 33/37, File 42/52
#
# Loading Subset 33/37, File 43/52
#
# Loading Subset 33/37, File 44/52
#
# Loading Subset 33/37, File 45/52
#
# Loading Subset 33/37, File 46/52
#
# Loading Subset 33/37, File 47/52
#
# Loading Subset 33/37, File 48/52
#
# Loading Subset 33/37, File 49/52
#
# Loading Subset 33/37, File 50/52
#
# Loading Subset 33/37, File 51/52
#
# Loading Subset 33/37, File 52/52
#
# Loading Subset 34/37, File 1/28
#
# Loading Subset 34/37, File 2/28
#
# Loading Subset 34/37, File 3/28
#
# Loading Subset 34/37, File 4/28
#
# Loading Subset 34/37, File 5/28
#
# Loading Subset 34/37, File 6/28
#
# Loading Subset 34/37, File 7/28
#
# Loading Subset 34/37, File 8/28
#
# Loading Subset 34/37, File 9/28
#
# Loading Subset 34/37, File 10/28
#
# Loading Subset 34/37, File 11/28
#
# Loading Subset 34/37, File 12/28
#
# Loading Subset 34/37, File 13/28
#
# Loading Subset 34/37, File 14/28
#
# Loading Subset 34/37, File 15/28
#
# Loading Subset 34/37, File 16/28
#
# Loading Subset 34/37, File 17/28
#
# Loading Subset 34/37, File 18/28
#
# Loading Subset 34/37, File 19/28
#
# Loading Subset 34/37, File 20/28
#
# Loading Subset 34/37, File 21/28
#
# Loading Subset 34/37, File 22/28
#
# Loading Subset 34/37, File 23/28
#
# Loading Subset 34/37, File 24/28
#
# Loading Subset 34/37, File 25/28
#
# Loading Subset 34/37, File 26/28
#
# Loading Subset 34/37, File 27/28
#
# Loading Subset 34/37, File 28/28
#
# Loading Subset 35/37, File 1/22
#
# Loading Subset 35/37, File 2/22
#
# Loading Subset 35/37, File 3/22
#
# Loading Subset 35/37, File 4/22
#
# Loading Subset 35/37, File 5/22
#
# Loading Subset 35/37, File 6/22
#
# Loading Subset 35/37, File 7/22
#
# Loading Subset 35/37, File 8/22
#
# Loading Subset 35/37, File 9/22
#
# Loading Subset 35/37, File 10/22
#
# Loading Subset 35/37, File 11/22
#
# Loading Subset 35/37, File 12/22
#
# Loading Subset 35/37, File 13/22
#
# Loading Subset 35/37, File 14/22
#
# Loading Subset 35/37, File 15/22
#
# Loading Subset 35/37, File 16/22
#
# Loading Subset 35/37, File 17/22
#
# Loading Subset 35/37, File 18/22
#
# Loading Subset 35/37, File 19/22
#
# Loading Subset 35/37, File 20/22
#
# Loading Subset 35/37, File 21/22
#
# Loading Subset 35/37, File 22/22
#
# Loading Subset 36/37, File 1/42
#
# Loading Subset 36/37, File 2/42
#
# Loading Subset 36/37, File 3/42
#
# Loading Subset 36/37, File 4/42
#
# Loading Subset 36/37, File 5/42
#
# Loading Subset 36/37, File 6/42
#
# Loading Subset 36/37, File 7/42
#
# Loading Subset 36/37, File 8/42
#
# Loading Subset 36/37, File 9/42
#
# Loading Subset 36/37, File 10/42
#
# Loading Subset 36/37, File 11/42
#
# Loading Subset 36/37, File 12/42
#
# Loading Subset 36/37, File 13/42
#
# Loading Subset 36/37, File 14/42
#
# Loading Subset 36/37, File 15/42
#
# Loading Subset 36/37, File 16/42
#
# Loading Subset 36/37, File 17/42
#
# Loading Subset 36/37, File 18/42
#
# Loading Subset 36/37, File 19/42
#
# Loading Subset 36/37, File 20/42
#
# Loading Subset 36/37, File 21/42
#
# Loading Subset 36/37, File 22/42
#
# Loading Subset 36/37, File 23/42
#
# Loading Subset 36/37, File 24/42
#
# Loading Subset 36/37, File 25/42
#
# Loading Subset 36/37, File 26/42
#
# Loading Subset 36/37, File 27/42
#
# Loading Subset 36/37, File 28/42
#
# Loading Subset 36/37, File 29/42
#
# Loading Subset 36/37, File 30/42
#
# Loading Subset 36/37, File 31/42
#
# Loading Subset 36/37, File 32/42
#
# Loading Subset 36/37, File 33/42
#
# Loading Subset 36/37, File 34/42
#
# Loading Subset 36/37, File 35/42
#
# Loading Subset 36/37, File 36/42
#
# Loading Subset 36/37, File 37/42
#
# Loading Subset 36/37, File 38/42
#
# Loading Subset 36/37, File 39/42
#
# Loading Subset 36/37, File 40/42
#
# Loading Subset 36/37, File 41/42
#
# Loading Subset 36/37, File 42/42
#
# Loading Subset 37/37, File 1/17
#
# Loading Subset 37/37, File 2/17
#
# Loading Subset 37/37, File 3/17
#
# Loading Subset 37/37, File 4/17
#
# Loading Subset 37/37, File 5/17
#
# Loading Subset 37/37, File 6/17
#
# Loading Subset 37/37, File 7/17
#
# Loading Subset 37/37, File 8/17
#
# Loading Subset 37/37, File 9/17
#
# Loading Subset 37/37, File 10/17
#
# Loading Subset 37/37, File 11/17
#
# Loading Subset 37/37, File 12/17
#
# Loading Subset 37/37, File 13/17
#
# Loading Subset 37/37, File 14/17
#
# Loading Subset 37/37, File 15/17
#
# Loading Subset 37/37, File 16/17
#
# Loading Subset 37/37, File 17/17

# %%
# Create seurat object
rna <- t(data.matrix(bind_rows(z_list))) * 0  # pseudo rna counts
colnames(rna) <- do.call("c", unname(cell_name_list))
rownames(rna) <- paste0("rna-", seq_len(nrow(rna)))
obj <- CreateSeuratObject(counts = rna, assay = "rna")

z <- data.matrix(bind_rows(z_list))
c <- z[, 1:K]
colnames(c) <- paste0("c_", seq_len(ncol(c)))
rownames(c) <- colnames(obj)
obj[["c"]] <- CreateDimReducObject(embeddings = c, key = "c_", assay = "rna")

obj@meta.data$batch <- factor(x = do.call("c", unname(subset_name_list)), levels = subset_names)
table(obj@meta.data$batch)[unique(obj@meta.data$batch)]

obj

# %%
# Generate UMAP for visualization
obj <- RunUMAP(obj, reduction = 'c', dims = 1:K, reduction.name = 'c.umap')
SaveH5Seurat(obj, pj(output_dir, "obj.h5seurat"), overwrite = TRUE)
# obj <- LoadH5Seurat(pj(output_dir, "obj.h5seurat"), reductions = "c.umap")

# %%
# set groups for highlighting
obj@meta.data$highlight <- "Unselected"
select_mask <- obj@meta.data$batch %in% subset_names[35:37]

cell_label <- gsub(" cell", "", read.csv(pj(output_dir, "label_gt.csv"), header = F)[, 1])
obj@meta.data$highlight[select_mask] <- cell_label

# Set colors
cell_label_unique <- unique(cell_label)
labels <- str_sort(cell_label_unique)

col_8 <- c("#8FC36D", "#f54646", "#4472c4", "#5d00ff", "#ff69b4", "#0077ff", "#fff300", "#008000", "#ad6800", "#0000ff")

pal <- col_8
label_to_color <- list()
for (i in seq_along(labels)) {
    label_to_color[[labels[i]]] <- pal[i]
}
cols <- c("#E5E5E5")
for (label in labels) {
    cols <- c(cols, label_to_color[[label]])
}

order <- c(rev(labels), "Unselected")


# plot
p1 <- dim_plot(obj, w = L+2, h = L, reduction = 'c.umap', no_axes = T, order = order, raster = F, rater_dpi = 600,
              split.by = NULL, group.by = "highlight", label = F, repel = T, label.size = 4, pt.size = 0.1, 
              shuffle = F, cols = cols, legend = T, return_plt = T, save_path = pj(output_dir, paste(o$task,
              o$method, o$experiment, o$model, o$init_model, "c_merged_label_l1", sep = "_"))) +
    labs(colour = "Seurat cell type")

# %%
cell_label <- gsub(" cells", "", read.csv(pj(output_dir, "label_transferred.csv"), header = F)[, 1])
obj@meta.data$highlight[select_mask] <- cell_label

# Set colors
cell_label_unique <- unique(cell_label)
labels <- str_sort(cell_label_unique)

col_13 <- c("#8FC36D", "#f54646", "#ff00ff", "#4472c4", "#82B4ed",  "#ff69b4", "#14e6e6", "#D4aaff", "#fff300", "#008000", "#eee8aa", "#2f4f4f", "#ad6800")

pal <- c(col_13, "#0000ff")
label_to_color <- list()
for (i in seq_along(labels)) {
    label_to_color[[labels[i]]] <- pal[i]
}
cols <- c("#E5E5E5")
for (label in labels) {
    cols <- c(cols, label_to_color[[label]])
}

order <- c(rev(labels), "Unselected")

# plot
p2 <- dim_plot(obj, w = L+2, h = L, reduction = 'c.umap', no_axes = T, order = order, raster = F, rater_dpi = 600,
              split.by = NULL, group.by = "highlight", label = F, repel = T, label.size = 4, pt.size = 0.1, 
              shuffle = F, cols = cols, legend = T, return_plt = T, save_path = pj(output_dir, paste(o$task,
              o$method, o$experiment, o$model, o$init_model, "c_merged_label_transfer", sep = "_"))) +
    labs(colour = "MIRACLE cell type")

# %%
w = 2 * (L + 1.5)
h = L
plt_size(w, h)
plt <- p2 | p1 
plt
# Out:
# plot without title

# %%
save_dir <- "./analysis/fig"
mkdir(save_dir, remove_old = F)
ggsave(plot = plt, file = pj(save_dir, "label_transfer_tissues_umap.png"), width = w, height = h, limitsize = F)
ggsave(plot = plt, file = pj(save_dir, "label_transfer_tissues_umap.pdf"), width = w, height = h, limitsize = F)
